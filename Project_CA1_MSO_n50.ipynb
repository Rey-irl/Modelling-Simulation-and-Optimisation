# %% [markdown]
# <a href="https://colab.research.google.com/github/Rey-irl/Modelling-Simulation-and-Optimisation/blob/main/Project_CA1_MSO_n50.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Prelude" data-toc-modified-id="Prelude-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Prelude</a></span></li><li><span><a href="#Utilities-(as-before)" data-toc-modified-id="Utilities-(as-before)-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Utilities (as before)</a></span></li><li><span><a href="#Finding-Shortest-Path-(as-before)" data-toc-modified-id="Finding-Shortest-Path-(as-before)-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Finding Shortest Path (as before)</a></span></li><li><span><a href="#Finding-Shortest-Delivery-Route-(as-before)" data-toc-modified-id="Finding-Shortest-Delivery-Route-(as-before)-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Finding Shortest Delivery Route (as before)</a></span></li><li><span><a href="#Time-Handling" data-toc-modified-id="Time-Handling-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Time Handling</a></span></li><li><span><a href="#Class-Recorder" data-toc-modified-id="Class-Recorder-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Class Recorder</a></span></li><li><span><a href="#Class-Parcel" data-toc-modified-id="Class-Parcel-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Class Parcel</a></span></li><li><span><a href="#Class-Customer" data-toc-modified-id="Class-Customer-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Class Customer</a></span></li><li><span><a href="#Class-Driver" data-toc-modified-id="Class-Driver-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Class Driver</a></span></li><li><span><a href="#Class-Delivery-Centre" data-toc-modified-id="Class-Delivery-Centre-10"><span class="toc-item-num">10&nbsp;&nbsp;</span>Class Delivery Centre</a></span></li><li><span><a href="#Simulation" data-toc-modified-id="Simulation-11"><span class="toc-item-num">11&nbsp;&nbsp;</span>Simulation</a></span><ul class="toc-item"><li><span><a href="#Parameters-from-Specification" data-toc-modified-id="Parameters-from-Specification-11.1"><span class="toc-item-num">11.1&nbsp;&nbsp;</span>Parameters from Specification</a></span></li><li><span><a href="#Generate-Input-Data" data-toc-modified-id="Generate-Input-Data-11.2"><span class="toc-item-num">11.2&nbsp;&nbsp;</span>Generate Input Data</a></span></li><li><span><a href="#Simulation-Routine" data-toc-modified-id="Simulation-Routine-11.3"><span class="toc-item-num">11.3&nbsp;&nbsp;</span>Simulation Routine</a></span></li><li><span><a href="#Model-Verification" data-toc-modified-id="Model-Verification-11.4"><span class="toc-item-num">11.4&nbsp;&nbsp;</span>Model Verification</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Prelude

# %%
import matplotlib.pyplot as plt
import pulp
import math
import random
import pandas as pd
import numpy as np
import time
import simpy

# %% [markdown]
# # 2. Utilities

# %% [markdown]
# ## Points and Distances

# %%
def dist(p1, p2):
    (x1, y1) = p1
    (x2, y2) = p2
    return int(math.sqrt((x1-x2)**2+(y1-y2)**2))

# %% [markdown]
# ## Graphs

# %%
def generateRandomGraph(n, x0, y0, r):

    def rounding(x):
        return int(math.floor(x/10))*10

    x0 = rounding(x0)
    y0 = rounding(y0)
    gridsize = rounding(r / math.sqrt(n) * 1.4)
    r = int(math.floor(r/gridsize))*gridsize
    split = int(2*r/gridsize)+1
    X = np.linspace(x0-r, x0+r, split)
    Y = np.linspace(y0-r, y0+r, split)
    P = [ (int(x), int(y)) for x in X for y in Y if dist((x,y), (x0,y0)) < r ]
    P = random.sample(P, k=n)

    E = []

    def addEdge(p, q):
        if p in P and q in P and (p, q) not in E and (q, p) not in E:
            E.append((p, q))
    def addDiagonalEdge(p, q):
        (xp, yp) = p
        (xq, yq) = q
        if p in P and q in P and (xp, yq) not in P and (xq, yp) not in P and (p, q) not in E and (q, p) not in E:
            E.append((p, q))

    for (x, y) in P:
        addEdge( (x, y), (x, y+gridsize) )
        addEdge( (x, y), (x, y-gridsize) )
        addEdge( (x, y), (x+gridsize, y) )
        addEdge( (x, y), (x-gridsize, y) )
        addDiagonalEdge( (x, y), (x+gridsize, y+gridsize) )
        addDiagonalEdge( (x, y), (x+gridsize, y-gridsize) )
        addDiagonalEdge( (x, y), (x-gridsize, y+gridsize) )
        addDiagonalEdge( (x, y), (x-gridsize, y-gridsize) )

    return sorted(P), sorted(E)

# %%
def plotGraph(P, E, col='b', grid=False):
    fig = plt.gcf()
    fig.set_size_inches(6, 6)
    if not grid:
        plt.axis('off')
    plt.plot( [ p[0] for p in P ], [ p[1] for p in P ], col+'o', lw=1, ms=3)
    for (p, q) in E:
        plt.plot( [ p[0], q[0] ], [ p[1], q[1] ], col+'-o', lw=1, ms=3)
    if grid:
        plt.grid()

# %%
# Personal Student ID: x23127635
random.seed(0)
#generateRandomGraph(nodes,size of the map )
V, E = generateRandomGraph(150, 5000, 5000, 4500)
plotGraph(V, E)

# %%
#The random generation may result in a graph consisting of multiple not connected subgraphs.
#Split a graph into not connected subgraphs, if any.

def subgraph(P, E):
    P = P.copy()
    E = E.copy()
    PP = [ P[0] ]
    EE = []
    P = P[1:]
    extended = True
    while extended:
        extended = False
        for (a, b) in E:
            if a in PP and b in P:
                PP.append(b)
                P.remove(b)
                EE.append((a, b))
                E.remove((a, b))
                extended = True
                break
            if a in P and b in PP:
                PP.append(a)
                P.remove(a)
                EE.append((a, b))
                E.remove((a, b))
                extended = True
                break
            if a in PP and b in PP:
                EE.append((a, b))
                E.remove((a, b))
                extended = True
                break
    return PP, EE, P, E

# %%
def generateGraph(n, x0, y0, r):
    P, E = generateRandomGraph(n, x0, y0, r)
    P0, _, P1, _ = subgraph(P, E)
    while len(P1)>0:
        (p, q) = nearest(P0, P1)
        E.append((p, q))
        P0, _, P1, _ = subgraph(P, E)
    return P, E

# %%
random.seed(0)
V, E = generateGraph(100, 5000, 5000, 4500)
plotGraph(V, E)

# %%
random.seed(0)
V, E = generateGraph(100, 5000, 5000, 4500)
plotGraph(V, E)

# %%
i=0
random.seed(i)
P, E = generateGraph(100, 4000, 4000, 4000)
print("Graph for seed", i, "has", len(P), "vertices and", len(E), "edges")
plotGraph(P, E)
plt.show()
# Out:
# Graph for seed 0 has 100 vertices and 136 edges

# %% [markdown]
# ## Lists and Paths

# %%
def pathLength(P):
    return 0 if len(P)<=1 else \
            dist(P[0], P[1])+pathLength(P[1:])

# %%
def reverse(P):
    return [ P[-i] for i in range(1,len(P)+1) ]

# %%
def index(x, L):
    for i in range(len(L)):
        if x==L[i]:
            return i
    return None

# %%
def addWithoutDuplicates(L, X):
    for i in range(len(X)):
        if X[i] not in L:
            L.append(X[i])
    return L

# %% [markdown]
# ## Generate Customer Locations

# %%
def splitEdgeRandomly(V, E, s):
    A, B = s
    p = random.uniform(0.3,0.7)
    x = int(A[0]+p*(B[0]-A[0]))
    y = int(A[1]+p*(B[1]-A[1]))
    t = (x,y)
    E.remove(s)
    E.append((A, t))
    E.append((t, B))
    V.append(t)
    return (V, E), t

# %%
def generateRandomTargets(V, E, n=5):
    V, E = V.copy(), E.copy()
    T = []
    # we want to ensure that the beginning of the
    # sequence of points generated randomly stays
    # the same
    mindist = 300
    while len(T)<n:
        s = random.choice(E)
        A, B = s
        if dist(A,B)>mindist: # avoid targets placed narrowly
            (V, E), t = splitEdgeRandomly(V, E, s)
            T.append(t)
    return sorted(T)

# %% [markdown]
# ## Add Targets

# %%
def addTargets(M, T):
    V, E = M
    E = E.copy()
    V = V.copy()
    for t in T:
        minD = math.inf
        minE = None
        for e in E:
            P, Q = e
            distT = dist(P, t)+dist(t, Q)-dist(P, Q)
            if distT < minD:
                minD = distT
                minE = e
        P, Q = minE
        E.remove( (P, Q) )
        E.append( (P, t) )
        E.append( (t, Q) )
        V.append(t)
    return V, E

# %% [markdown]
# ## PlotMap with Delivery Route

# %%
def plotMap(G, T=[], P=[], W=None,
            style='r-o', lw=1, ms=3,
            styleT='go', msT=5,
            styleP='b-o', lwP=3, msP=1,
            stylePT='go', msPT=7,
            styleW='bo', msW=9,
            text=None, grid=False):
    fig = plt.gcf()
    fig.set_size_inches(6, 6)
    V, E = G

    if not grid:
        plt.axis('off')
    plt.plot( [ p[0] for p in V ], [ p[1] for p in V ], 'ro', lw=lw, ms=ms)
    for (p, q) in E:
        plt.plot( [ p[0], q[0] ], [ p[1], q[1] ], 'r-o', lw=lw, ms=ms)
    for t in T:
        plt.plot( [ t[0] ], [ t[1] ],
                 styleT, ms=msT)
    plt.plot( [ p[0] for p in P ],
              [ p[1] for p in P ],
              styleP, lw=lwP, ms=msP)
    for p in P:
        if p in T:
            plt.plot( [ p[0] ], [ p[1] ],
                      stylePT, ms=msPT)
    if W is not None:
        plt.plot( [ W[0] ], [ W[1] ],
                      styleW, ms=msW)
    if text is not None:
        maxX = max([p[0] for p in V])
        plt.text(0.8*maxX, 0, text)
    if grid:
        plt.grid()
    plt.show()

# %% [markdown]
# ## Generate Warehouse Location

# %% [markdown]
# This is a blind random generation as it would be needed for a Monte-Carlo Optimisation.
# You may improve this algorithm to reduce the search space.

# %%
def generateWarehouseLocation(M):
    V, _ = M
    W = random.sample(V, k=1)[0]
    return W

# %% [markdown]
# ## Generate Data

# %%
def generateData(seed=None, nodes=100, customers=150,
                 plot=False, log=False):

    if seed is None:

        print("Usage:  M, C = generateData(seed=None, ")
        print("                            nodes=100, customers=50, ")
        print("                            plot=False, log=False)")
        print("")
        print("  seed  the seed value to be used for data generation. ")
        print("        To test the application use seed=0, it will create")
        print("        a small map, with a very few customer locations and")
        print("        a small set of delivery data.")
        print("")
        print("  nodes the number of intersections (vertices) in the generated map")
        print("")
        print("  customers  the number of customers generated on the map")
        print("")
        print("  log   Controls print output during data generation.")
        print("")
        print("  plot  Controls graphical output during data generation.")
        print("")
        print("Returns:")
        print("")
        print("  M = (V, E) is the generated map given as a graph")
        print("    where V is a list of vertices, with each vertice ")
        print("    given as a pair (x, y) of integer coordinates, ")
        print("    and E is a list of edges, with each edge given")
        print("    as a pair (A, B) of vertices, with each vertex again")
        print("    given as a pair (x, y) of integer coordinates")
        print("")
        # print("  W ∈ V  is the location of the distribution warehouse")
        # print("    given as a pair (x, y) of integer coordinates")
        # print("")
        print("  C is a list of customer locations")
        print("    given as pairs (x, y) of integer coordinates on or near")
        print("    existing edges E. To integrate a set of customer locations")
        print("    into a given map M = (V, E), use addTarget(M, C)")
        print("")

        seed = 0

    if seed==0:          # generate very simple test data
        nodes = 20       # number of points in map
        customers = 5    # number of  customers
        grid = True

    else:
        grid = False

    random.seed(seed)

    V, E = generateGraph(nodes, 4000, 4000, 4000)

    C = generateRandomTargets(V, E, customers)

    if log:
        print(f"Generated map with {nodes:d} nodes and "
              f"{customers:d} customer locations")
    if plot:
        label="" if seed==0 else f"seed={seed:4d}"
        plotMap((V, E), T=C, text=label, grid=grid)

    return (V, E), C

# %%
D1 = generateData(0)
D2 = generateData(0)
D1 == D2
# Out:
# True

# %% [markdown]
# ### General Help Message

# %%
# If you use generateData() without any parameters you will get a general help message

M, C = generateData()
# Out:
# Usage:  M, C = generateData(seed=None,
#                             nodes=100, customers=50,
#                             plot=False, log=False)
#
#   seed  the seed value to be used for data generation.
#         To test the application use seed=0, it will create
#         a small map, with a very few customer locations and
#         a small set of delivery data.
#
#   nodes the number of intersections (vertices) in the generated map
#
#   customers  the number of customers generated on the map
#
#   log   Controls print output during data generation.
#
#   plot  Controls graphical output during data generation.
#
# Returns:
#
#   M = (V, E) is the generated map given as a graph
#     where V is a list of vertices, with each vertice
#     given as a pair (x, y) of integer coordinates,
#     and E is a list of edges, with each edge given
#     as a pair (A, B) of vertices, with each vertex again
#     given as a pair (x, y) of integer coordinates
#
#   C is a list of customer locations
#     given as pairs (x, y) of integer coordinates on or near
#     existing edges E. To integrate a set of customer locations
#     into a given map M = (V, E), use addTarget(M, C)

# %% [markdown]
# ## Real Sample Data

# %%
# Sample data for the required simulation.
data =generateData(7635, plot=True, log=True)
# Out:
# Generated map with 100 nodes and 150 customer locations

# %%
#Save data as pickle file
import pickle
with open('data.pickled', 'wb') as f:
    pickle.dump(data, f)

# %%
# Assigning elements from data (pickle file)
# M: Map of the townships
# C: Customers addresses
M, C = data

# %%
#Identify the points in the grid above: vertices and edges
V, E = M

# %%
#The Warehouse address
random.seed(0)
W= generateWarehouseLocation(M)
W
# Out:
# (3440, 6800)

# %%
plotMap((V, E), T=C, W=W)

# %% [markdown]
# ## Loading Sample Data

# %%
import pickle
with open('data.pickled', 'rb') as f:
    M, C = pickle.load(f)

# %%
#Split the map into Vertices and Edges:
V, E = M

# %%
#Pick a random location for the Warehouse at one of the intersections (vertices) on the map
random.seed(7635)
W = generateWarehouseLocation(M)

# %%
plotMap(M, T=C, P=[], W=W, text="seed=7635")

# %%
W
# Out:
# (1760, 4000)

# %% [markdown]
# ## 2.11 Time Handling

# %% [markdown]
# **Convention:** In this project we measure time in seconds. The simulation will start at 0:00. Time related methods will be added as they are needed.

# %% [markdown]
# `timestamp(t)` generates a timestamp string in the form `[dd] hh:mm:ss.d`

# %%
    def timestamp(t):
        day = int(t)//(24*3600)
        t = t - day*24*3600
        hour = int(t)//3600
        t = t - hour*3600
        mins = int(t)//60
        t = t - mins*60
        secs = int(math.floor(t))
        t = int(math.floor((t - secs)*10))
        return f"[{day:2d}] {hour:02d}:{mins:02d}:{secs:02d}.{t:1d}"

# %%
timestamp(24*3600*3+17*3600+615.1)
# Out:
# '[ 3] 17:10:15.0'

# %%
def nextHour(env, hour):
    beginningOfDay = int(env.now//(24*3600))*24*3600
    timeOfDay = env.now-beginningOfDay
    if hour*3600 > timeOfDay:
        return hour*3600 - timeOfDay
    else:
        return hour*3600 + 24*3600 - timeOfDay

# %%
def day(now):
    return int(now//(24*3600))

# %% [markdown]
# ## Plotting Routines

# %%
import scipy.stats as stats

def histplot(data, title="", xlabel="",
             width=None, height=None):

    minx = min(data)
    maxx = max(data)
    μ = np.mean(data)
    σ = np.std(data)

    fig = plt.figure()
    fig.set_figwidth(width if width is not None else 4)
    fig.set_figheight(height if height is not None else 2.5)
    ax = fig.gca()

    hist=plt.hist(data, density=True)
    plt.xlabel(xlabel)
    plt.ylabel('Density')
    plt.title(title)

    x = np.linspace(minx, maxx, 100)
    y = [ stats.norm(loc=μ, scale=σ).pdf(p) for p in x]
    ax.plot(x, y, lw=1, color='red')
    ax.axvline(x=μ, color='red')
    maxy = max(max(y), max(hist[0]))
    ax.text(maxx, maxy,
            f'μ={μ:2.2f}\nσ={σ:2.2f}',
            ha='right', va='top',
            color='red', fontsize=12)
    ax.grid(True)
    plt.show()

# %%
def dailyPlot(data,
              title="", ylabel="",
              width=None, height=None):

    days = len(data)

    fig = plt.figure()
    fig.set_figwidth(width if width is not None else 6)
    fig.set_figheight(height if height is not None else 2)

    ax = fig.gca()
    diff = (max(data)-min(data))*0.1
    ymin = int(math.floor(min(data)-diff))
    ymax = int(math.ceil(max(data)+diff))
    ax.set_xlim(-1, days)
    ax.set_ylim(ymin, ymax)
    ax.grid(True)

    ms = 2 if len(data)>100 else 5
    lw = 0.5 if len(data)>100 else 1

    x = np.arange(0, len(data))
    y = np.array([ y for y in data ])
    b, m = np.polynomial.polynomial.polyfit(x, y, 1)

    plt.plot(x, y, 'bo-', linewidth=lw, markersize=ms)
    plt.plot(x, m*x+b, 'r-')

    plt.xlabel('Day')
    plt.ylabel(ylabel)
    plt.title(title)
    plt.show()

# %% [markdown]
# # 3. Finding Shortest Path

# %% [markdown]
# ## 3.1 The Algorithm

# %% [markdown]
# This is the $A^{*}$ algorithm introduced in Week 3.

# %%
def dist(p1, p2):
    (x1, y1) = p1
    (x2, y2) = p2
    return int(math.sqrt((x1-x2)**2+(y1-y2)**2))

# %%
def pathLength(P):
    return 0 if len(P)<=1 else \
            dist(P[0], P[1])+pathLength(P[1:])

# %%
def shortestPath(M, A, B):

    def h(p):
        return pathLength(p)+dist(p[-1],B)

    # candidates C are pairs of the path so far and
    # the heuristic function of that path,
    # sorted by the heuristic function, as maintained by
    # insert function
    def insert(C, p):
        hp = h(p)
        c = (p, hp)
        for i in range(len(C)):
            if C[i][1]>hp:
                return C[:i]+[c]+C[i:]
        return C+[c]

    V, E = M
    assert(A in V and B in V)
    C = insert([], [A])

    while len(C)>0:
        # take the first candidate out of the list of candidates
        path, _ = C[0]
        C = C[1:]
        if path[-1]==B:
            return path
        else:
            for (x, y) in E:
                if path[-1]==x and y not in path:
                    C = insert(C, path+[y])
                elif path[-1]==y and x not in path:
                    C = insert(C, path+[x])
    return None

# %% [markdown]
# ## 3.2 Testing

# %%
A = C[0]
B = C[-1]

# %%
MAB = addTargets(M, [A, B])

# %%
plotMap(MAB, T=[A, B])

# %%
P = shortestPath(MAB, A, B)

# %%
plotMap(MAB, T=[A, B], P=P)

# %% [markdown]
# # 4. Finding Shortest Delivery Route

# %% [markdown]
# ## Iterative Integer Programming

# %%
def createTables(M, T):

    def reverse(P):
        return [ P[-i] for i in range(1,len(P)+1) ]

    def index(x, L):
        for i in range(len(L)):
            if x==L[i]:
                return i
        return None

    n = len(T)
    d = [ [ math.inf for t in T ] for t in T ]
    p = [ [ None for t in T ] for t in T ]
    for i in range(n):
        d[i][i] = 0
        p[i][i] = [ T[i] ]
    for i in range(n):
        for j in range(n):
            if p[i][j] is None:
                s = shortestPath(M, T[i], T[j])
                d[i][j] = d[j][i] = pathLength(s)
                p[i][j] = s
                p[j][i] = reverse(s)
                for m in range(len(s)-1):
                    smi = index(s[m], T)
                    if smi is None:
                        continue
                    for l in range(m+1, len(s)):
                        sli = index(s[l], T)
                        if sli is None:
                            continue
                        sub = s[m:l+1]
                        if p[smi][sli] is None:
                            p[smi][sli] = sub
                            p[sli][smi] = reverse(sub)
                            d[smi][sli] = d[sli][smi] = pathLength(sub)
    return d,p

# %%
def roundtrips(x, n):

    def isElem(x, l):
        for i in range(len(l)):
            if l[i]==x:
                return True
        return False

    def startpoint(trips):
        for i in range(n):
            for t in trips:
                if isElem(i, t):
                    break
            else:
                return i

    def totalLength(trips):
        s=0
        for i in range(0, len(trips)):
            s += len(trips[i])-1
        return s

    trips = []
    while totalLength(trips)<n:
        start = startpoint(trips)
        trip = [ start ]
        i = start
        while len(trip) < n-totalLength(trips):
            for j in range(0, n):
                if pulp.value(x[i][j])==1:
                    trip.append(j)
                    i=j
                    break
            if pulp.value(x[trip[-1]][start])==1:
                trip.append(start)
                break
        trips.append(trip)
    return sorted(trips, key=lambda t: len(t), reverse=True)

# %%
import time

def createLoop(M, T, timing=False):

    if timing:
        start_time = time.time()
        last_time = time.time()

    D, P = createTables(M, T)   # These are the distances between customers and warehouse only

    if timing:
        print(f"createTables:   {time.time()-start_time:6.2f}s")
        last_time = time.time()

    n = len(T)

    if n==1:
        return T

    # create variables
    x = pulp.LpVariable.dicts("x", ( range(n), range(n) ),
                            lowBound=0, upBound=1, cat=pulp.LpInteger)
    # create problem
    prob = pulp.LpProblem("Loop",pulp.LpMinimize)
    # add objective function
    prob += pulp.lpSum([ D[i][j]*x[i][j]
                             for i in range(n) for j in range(n) ])
    # add constraints
    constraints=0
    for j in range(n):
        prob += pulp.lpSum([ x[i][j] for i in range(n) if i!=j ]) ==1
    constraints += n
    for i in range(n):
        prob += pulp.lpSum([ x[i][j] for j in range(n) if i!=j ]) ==1
    constraints += n
    for i in range(n):
        for j in range(n):
            if i!=j:
                prob += x[i][j]+x[j][i] <= 1
                constraints += 1
    # initialise solver
    solvers = pulp.listSolvers(onlyAvailable=True)
    solver = pulp.getSolver(solvers[0], msg=0)
    prob.solve(solver)

    if timing:
        print(f"Solver:         {time.time()-last_time:6.2f}s {constraints:6,d} Constraints")
        last_time = time.time()

    trips = roundtrips(x, n)
    while len(trips)>1:
        longest = max([ len(t) for t in trips ])
        for t in trips:
            if len(t)<longest:
                prob += pulp.lpSum([ x[t[i]][t[i+1]] + x[t[i+1]][t[i]]
                                        for i in range(0,len(t)-1) ]) <= len(t)-2
                constraints += 1
            else:
                longest = math.inf
        prob.solve(solver)

        if timing:
            print(f"Solver:         {time.time()-last_time:6.2f}s {constraints:6,d} Constraints")
            last_time = time.time()

        trips = roundtrips(x, n)

    trip = trips[0]
    loop = []
    for k in range(len(trip)-1):
        sub = P[trip[k]][trip[k+1]]
        loop += sub if len(loop)==0 else sub[1:]

    if timing:
        print(f"createLoop:     {time.time()-start_time:6.2f}s")

    return loop

# %% [markdown]
# ## 4.2 Heuristic Algorithm

# %%
def FW(M):

    V, E = M

    n = len(V)
    d = [ [ math.inf for j in range(n) ] for i in range(n) ]
    p = [ [ None for j in range(n) ] for i in range(n) ]

    for (A, B) in E:
        a = V.index(A)
        b = V.index(B)
        d[a][b] = d[b][a] = dist(A, B)
        p[a][b] = [A, B]
        p[b][a] = [B, A]

    for i in range(n):
        d[i][i] = 0
        p[i][i] = [V[i]]

    for k in range(n):
        for i in range(n):
            for j in range(n):
                dk = d[i][k] + d[k][j]
                if d[i][j] > dk:
                    d[i][j] = dk
                    p[i][j] = p[i][k][:-1] + p[k][j]

    return d, p

# %%
def createLoopH(M, T, timing=False):

    def makeLoop(L):
        loop = []
        for i in range(len(L)-1):
            A = L[i]
            B = L[i+1]
            a = V.index(A)
            b = V.index(B)
            sub = P[a][b]
            loop += sub if len(loop)==0 else sub[1:]
        return loop

    if timing:
        start_time = time.time()
        last_time = time.time()

    V, E = M
    D, P = FW(M)   # note these are the distances between all vertices in M (and T)

    if timing:
        print(f"createTables:   {time.time()-start_time:6.2f}s")
        last_time = time.time()

    W = T[0]
    customers = T[1:]
    if len(T)==1:
        L = T
    elif len(T)<=3:
        L = T + [T[0]]
    else:
        L = T[:3]+[T[0]]
        T = T[3:]
        while len(T)>0:
            minExt = math.inf
            minInd = None
            selInd = None
            for k in range(len(T)):
                C = T[k]
                c = V.index(C)
                for i in range(0, len(L)-1):
                    A = L[i]
                    B = L[i+1]
                    a = V.index(A)
                    b = V.index(B)
                    ext = D[a][c] + D[c][b] - D[a][b]
                    if ext<minExt:
                        minExt, minInd, selInd = ext, i+1, k
            L = L[:minInd]+[T[selInd]]+L[minInd:]
            T = T[:selInd]+T[selInd+1:]

    if timing:
        print(f"createLoopH:    {time.time()-start_time:6.2f}s")

    return makeLoop(L)

# %% [markdown]
# ## 4.3 Greedy Algorithm

# %%
def createLoopG(M, T, plot=False, timing=False):

    def makeLoop(L):
        loop = []
        for i in range(len(L)-1):
            A = L[i]
            B = L[i+1]
            a = V.index(A)
            b = V.index(B)
            sub = P[a][b]
            loop += sub if len(loop)==0 else sub[1:]
        return loop

    if timing:
        start_time = time.time()

    V, E = M
    D, P = FW(M)   # note these are the distances between all vertices in M (and T)

    if timing:
        print(f"Floyd-Warshall: {time.time()-start_time:6.2f}s")

    W = T[0]
    customers = T[1:]
    if len(T)==1:
        L = T
    elif len(T)<=3:
        L = T + [T[0]]
    else:
        L = T[:3]+[T[0]]
        T = T[3:]
        while len(T)>0:
            if plot:
                loop = makeLoop(L)
                plotMap(M, T=L, P=loop, w=W,
                        grid=True, text=f"{pathLength(loop):,d}m")
            minExt = math.inf
            minInd = None
            selInd = None
            for k in range(len(T)):
                C = T[k]
                c = V.index(C)
                for i in range(0, len(L)-1):
                    A = L[i]
                    B = L[i+1]
                    a = V.index(A)
                    b = V.index(B)
                    ext = D[a][c] + D[c][b] - D[a][b]
                    if ext<minExt:
                        minExt, minInd, selInd = ext, i+1, k
            L = L[:minInd]+[T[selInd]]+L[minInd:]
            T = T[:selInd]+T[selInd+1:]

    if timing:
        print(f"createLoopG:    {time.time()-start_time:6.2f}s")

    return makeLoop(L)

# %% [markdown]
# ### Delivering to 30 Customers

# %%
random.seed(0)
T = random.sample(C, k=len(C)//5)

# %%
len(T)
# Out:
# 30

# %%
MC = addTargets(M, T)

# %%
# Iterative Integer Programming
PC = createLoop(MC, [W] + T, timing=True)
# Out:
# createTables:     0.30s
# Solver:           0.39s    992 Constraints
# Solver:           0.24s    993 Constraints
# Solver:           0.23s    995 Constraints
# Solver:           0.24s    996 Constraints
# Solver:           0.28s    997 Constraints
# Solver:           0.21s    998 Constraints
# Solver:           0.21s    999 Constraints
# Solver:           0.22s  1,000 Constraints
# Solver:           0.26s  1,001 Constraints
# Solver:           0.28s  1,002 Constraints
# Solver:           0.40s  1,003 Constraints
# createLoop:       3.25s

# %%
plotMap(MC, T=T, W=W, P=PC, text=f"Path Length={pathLength(PC):3,d}m")

# %%
# Greedy Algorithm
PG = createLoopG(MC, [W]+T, timing= True)
# Out:
# Floyd-Warshall:   0.20s
# createLoopG:      0.21s

# %%
plotMap(MC, T=T, W=W, P=PG, text=f"Greedy Path Length={pathLength(PG):3,d}m")

# %%
# Heuristic Algorithm
PH = createLoopH(MC, [W]+T, timing=True)
# Out:
# createTables:     0.18s
# createLoopH:      0.19s

# %%
plotMap(MC, T=T, W=W, P=PH, text=f"Heuristic Path Length={pathLength(PH):3,d}m")

# %%
PH.reverse()

# %%
P == PH
# Out:
# False

# %% [markdown]
# # Class Recorder

# %% [markdown]
# We willl use a class Recorder as a reference point for capturing data during the simulation. There will be only one recorder. It will be created at the beginning of every simulation run. Every entity will carry a reference to the Recorder.

# %%
class Recorder:

    def __init__(self, env, M, W, C, days,
                 log=False, plot=False, timing=False):
        self.env = env
        self.M = M
        self.W = W
        self.C = C
        self.days = days
        self.log = log
        self.plot = plot

        self.timing = timing
        self.start_time = time.time()
        self.last_time = self.start_time
        self.cum_timer = {}

        Customer.REGISTER = []
        Parcel.REGISTER = []

        # create a data frame for records per working day
        self.daily = pd.DataFrame()
        self.daily['begin work at'] = [None]*days
        self.daily['end work at'] = [None]*days
        self.daily['dist'] = [None]*days
        self.daily['left'] = [None]*days
        self.daily['cost']=[None]*days #adding daily costs

    def timer(self, s):
        t = time.time()
        Δt = t-self.last_time
        if self.timing:
            print(f"==== t: {t-self.start_time:6.2f}s "
                  f"Δt: {Δt:6.2f}s [{s:s}]")
        if s in self.cum_timer:
            self.cum_timer[s] += Δt
        else:
            self.cum_timer[s] = Δt
        self.last_time = t

    def reportTimer(self):
        print(f"==== t: {self.total_time:6.2f}s Total")
        for k in sorted(self.cum_timer, key=lambda x: self.cum_timer[x], reverse=True):
            print(f"==== ΣΔt: {self.cum_timer[k]:6.2f}s "+ k)

    def trace(self, event):
        if self.log:
            print(timestamp(self.env.now), event)

    def recordDriverBeginsWork(self):
        self.trace("Driver arrives for work")
        self.daily.at[day(self.env.now), 'begin work at'] = int(round(self.env.now))

    def recordDriverEndsWork(self):
        self.trace("Driver goes home")
        self.daily.at[day(self.env.now), 'end work at'] = int(round(self.env.now))

    def recordTourLength(self, length):
        self.daily.at[day(self.env.now), 'dist'] = int(length)

    def recordParcelsLeftOver(self, numberOfParcels):
        self.trace(f"{numberOfParcels:d} left over for next day")
        self.daily.at[day(self.env.now), 'left'] = numberOfParcels

    def recordCost(self, HOURLY_RATE=30, MINIMUM_WORKING_DAY=60):
#        self.daily.at[day(self.env.now), 'cost'] = int(length)
        for i, row in self.daily.iterrows():
            working_time = (row['end work at']-row['begin work at'])//60
            tour_length = row['dist']
            electric_cargo_bike= (row['dist']//1000) * OPERATIONAL_COST
            hourly_cost = max(MINIMUM_WORKING_DAY, (working_time//60) * HOURLY_RATE)
            #self.daily.at[i, 'cost'] = (tour_length/hourly_cost)+ electric_cargo_bike
            self.daily.at[i,'cost'] = (tour_length//hourly_cost) + electric_cargo_bike

    def finish(self):
        # simulation is finished for good
        # by removing the simulation environment we can
        # pickle recorder
        self.recordCost()
        self.env = None
        self.total_time = time.time()-self.start_time
        self.daily['working time'] = (self.daily['end work at']-self.daily['begin work at'])//60


    def __stats__(self, column):
        d = self.daily[column].copy()
        return d.mean(), d.median(), d.std()

    def statsWorkingTime(self):
        return self.__stats__('working time')

    def histWorkingTime(self):
        histplot(self.daily['working time'],
                 xlabel='Working Time [min]',
                 title='Daily Working Time')

    def plotWorkingTime(self):
        dailyPlot(self.daily['working time'],
                  ylabel='Working Time [min]',
                  title='Daily Working Time')

    def statsTourLength(self):
        return self.__stats__('dist')

    def histTourLength(self):
        histplot(self.daily['dist'],
                 xlabel='Tour Length [m]',
                 title='Daily Tour Length')

    def plotTourLength(self):
        dailyPlot(self.daily['dist'],
                  ylabel='Tour Length [m]',
                  title='Daily Tour Length')

    def statsLeftOver(self):
        return self.__stats__('left')

    def histLeftOver(self):
        histplot(self.daily['left'],
                 xlabel='Left-Over Parcels',
                 title='Daily Left-Over Parcels')

    def plotLeftOver(self):
        dailyPlot(self.daily['left'],
                  ylabel='Number of Parcels',
                  title='Daily Left-Over Parcels')

    def statsCosts(self):
        return self.__stats__('cost')

    def histCosts(self):
        histplot(self.daily['cost'],
                 xlabel='Costs [€]',
                 title='Daily Costs')

    def plotCosts(self):
        dailyPlot(self.daily['cost'],
                  ylabel='Tour Cost [€]',
                  title='Daily Cost')

# %% [markdown]
# # Class Parcel

# %% [markdown]
# <img src='img/EventGraph Parcel.png' width=500/>

# %% [markdown]
# Parcels follow through a sequence of states:
# - processing
# - in transit (from manufacture to distribution centre)
# - arrived in distribution centre
# - ready for delivery
# - out for delivery
# - customer not present
# - returned to distribution centre
# - delivered

# %%
class Parcel:

    REGISTER = []

    def __init__(self, rec, i, cust, custIndex):
        self.rec = rec
        self.i = i  # row index in data frames of input data
        self.dest = cust.location
        self.custIndex = custIndex
        self.status = [ 'processing' ] # status record and
        self.timing = [ self.rec.env.now ]      # timing
        assert(len(Parcel.REGISTER)==i)
        Parcel.REGISTER += [ self ]

    # factory method ensures that there is only
    # one Parcel per location
    def getParcel(rec, i, location, custIndex):
        for p in Parcel.REGISTER:
            if p.i == i:
                return p
        return Parcel(rec, i, location, custIndex)


    def __str__(self):
        return f"Parcel: {self.i:3d} ({self.custIndex:3d})"

    def index(self):
        return self.i

    def destination(self):
        return self.dest

    def __reg(self, state):
        self.status += [ state ]
        self.timing += [ self.rec.env.now ]
        self.rec.trace(str(self)+" "+state)

    def arrivedAtDeliveryCentre(self):
        self.__reg('arr at delivery centre')

    def outForDelivery(self):
        self.__reg('out for delivery')

    def returnFromDelivery(self):
        self.__reg('return from delivery')

# %% [markdown]
# # Class Customer

# %% [markdown]
# <img src='img/EventGraph Customer.png' width=500/>

# %%
class Customer:

    REGISTER = []

    def __init__(self, rec, location):
        self.rec = rec
        self.location = location
        self.i = len(Customer.REGISTER)
        Customer.REGISTER += [ self ]
        self.atHome = True
        self.answersDoor = False
        self.parcelsReceived = []
        rec.env.process(self.process())

    def __str__(self):
        return f"Customer: {self.i:2d} {str(self.location):s}"

    # factory method ensures that there is only
    # one customer per location
    def getCustomer(rec, location):
        for c in Customer.REGISTER:
            if c.location == location:
                return c
        return Customer(rec, location)

    def leaveHouse(self):
        assert(self.atHome and not self.answersDoor)
        # self.rec.trace(str(self)+" leaves house")
        self.atHome = False

    def returnHome(self):
        assert(not self.atHome)
        # self.rec.trace(str(self)+" returns home")
        self.atHome = True

    def answerDoor(self):
        if self.atHome:
            yield self.rec.env.timeout(random.expovariate(1/AVERAGE_TIME_ANSWER_DOOR))
            self.rec.trace(str(self)+" answers door")
            self.answersDoor = True
        else:
            yield self.rec.env.timeout(WAIT_TIME_IF_CUSTOMER_DOESNT_ANSWER_DOOR)
            self.rec(str(self)+" not at home")

    def acceptParcel(self, parcel):
        assert(self.answersDoor)
        self.parcelsReceived += [parcel]
        self.rec.trace(str(self)+" accepts "+str(parcel))

    def signOff(self):
        assert(self.answersDoor)
        self.rec.trace(str(self)+" signs off")
        self.answersDoor = False

    def process(self):
        yield self.rec.env.timeout(nextHour(self.rec.env, 8))
        while day(self.rec.env.now)<self.rec.days:
            # in a refinement we may use random times
            self.leaveHouse()
            yield self.rec.env.timeout(nextHour(self.rec.env, 18))
            self.returnHome()
            yield self.rec.env.timeout(nextHour(self.rec.env, 8))

# %% [markdown]
# # Class Driver

# %% [markdown]
# <img src='img/EventGraph Driver.png' width=500/>

# %%
class Driver:

    def __init__(self, rec, DC):
        self.rec = rec
        self.DC = DC
        self.location = None
        self.parcels = None
        self.tour = None
        self.rec.env.process(self.process())

    # activity
    def __drive(self, target):
        assert(self.tour[0] == self.location)
        while self.location!=target:
            d = dist(self.location, self.tour[1])
            yield self.rec.env.timeout(d / AVERAGE_SPEED)
            self.location = self.tour[1]
            self.tour = self.tour[1:]
        assert(self.tour[0] == self.location == target)

    def arriveForWork(self):
        self.location = self.DC.W
        self.parcels = []
        self.returns = []
        self.tour = [ self.DC.W ]
        self.rec.recordDriverBeginsWork()

    def leaveForDelivery(self, tour, parcels):
        self.tour, self.parcels = tour, parcels
        self.rec.trace(f"Driver leaves for delivery " \
                       f"of {len(parcels):d} parcels")

    def process(self):
        yield self.rec.env.timeout(nextHour(self.rec.env, 18))
        while day(self.rec.env.now)<self.rec.days:
            self.arriveForWork()
            tour, parcels = self.DC.sendForDelivery()
            yield self.rec.env.timeout(PREP_TIME_PER_PARCEL*len(parcels))
            self.rec.recordTourLength(pathLength(tour))
            self.leaveForDelivery(tour, parcels)
            while len(self.parcels)>0:
                # drive to customer
                custLocation = self.parcels[0].dest
                cust = Customer.getCustomer(self.rec, custLocation)
                self.rec.trace("Driver drives to "+str(cust))
                yield from self.__drive(custLocation)
                self.rec.trace("Driver arrived at "+str(cust))
                # call at customer
                yield from cust.answerDoor()

                if cust.answersDoor:
                    while len(self.parcels)>0 and \
                            custLocation == self.parcels[0].dest:
                        cust.acceptParcel(self.parcels[0])
                        yield self.rec.env.timeout(random.expovariate(1/10))
                        self.parcels = self.parcels[1:]
                    cust.signOff()
                    yield self.rec.env.timeout(random.expovariate(1/10))
                else:
                    while len(self.parcels)>0 and  \
                            custLocation == self.parcels[0].dest:
                        self.returns += self.parcels[0]
                        self.parcels = self.parcels[1:]

            # return to delivery centre
            self.rec.trace("Driver returns to delivery centre")
            yield from self.__drive(self.DC.W)
            self.rec.trace("Driver arrived at delivery centre")

            for parcel in self.returns:
                self.DC.returnFromDelivery(parcel)
                yield self.rec.env.timeout(RETURN_TIME_PER_PARCEL)
            yield self.rec.env.timeout(600)

            self.rec.recordParcelsLeftOver(len(self.DC.parcels)+
                                           len(self.DC.leftOver))

            self.rec.recordDriverEndsWork()

            yield self.rec.env.timeout(nextHour(self.rec.env, 18))

# %% [markdown]
# # Class Delivery Centre

# %% [markdown]
# <img src="img/EventGraph Delivery Centre.png" width=500/>

# %%
class DeliveryCentre:

    def __init__(self, rec, M, W):
        self.rec = rec
        self.M = M
        self.W = W
        self.limit = 35000

        self.leftOver = []    # list of parcels
        self.parcels = []     # list of parcels scheduled for delivery
        self.dest = []        # list of unique customer destinations
        self.tour = None      # tour planned for delivery

    def __accept(self, parcel):
        custLoc = parcel.dest
        if custLoc not in self.dest:
            MT = addTargets(self.M, self.dest + [custLoc])
            self.rec.timer("addTarget")
            SH = createLoopH(MT, [self.W] + self.dest + [custLoc],
                             timing=self.rec.timing)
            self.rec.timer("createLoopH")
            if self.tour is None and pathLength(SH)<self.limit:
                self.parcels.append(parcel)
                self.dest += [custLoc]
            else:
                S = createLoop(MT, [self.W] + self.dest + [custLoc],
                               timing=self.rec.timing)
                self.rec.timer("createLoop")
                if pathLength(S)<self.limit:
                    self.parcels.append(parcel)
                    self.dest += [custLoc]
                    self.tour = S
                else:
                    self.leftOver.append(parcel)
        else:
            self.parcels.append(parcel)

    def acceptParcel(self, parcel):
        parcel.arrivedAtDeliveryCentre()
        self.__accept(parcel)

    def sendForDelivery(self):
        parcels = []
        if self.tour is None:
            MT = addTargets(self.M, self.dest)
            self.rec.timer("addTarget")
            self.tour = createLoop(MT, [self.W] + self.dest,
                                   timing=self.rec.timing)
            self.rec.timer("createLoop")
        tour = self.tour
        addresses = self.dest

        # pick parcels in sequence to be delivered
        for i in range(1, len(tour)-1):
            dest = tour[i]
            for p in self.parcels:
                if p.dest == dest and p not in parcels:
                    parcels += [p]
                    p.outForDelivery()

        # arrange the left overs
        L = self.leftOver
        self.tour = None
        self.parcels = []
        self.leftOver = []
        self.dest = []
        for p in L:
            self.__accept(p)

        if self.rec.plot:
            plotMap(self.rec.M, T=addresses, P=tour, W=tour[0],
                    text=f"Day {day(self.rec.env.now):2d}, {pathLength(tour):,d}m")

        return tour, parcels

    def returnFromDelivery(self, parcel):
        parcel.returnFromDelivery()
        self.__accept(parcel)

    def getInventory(self):
        return len(self.parcels)+len(self.leftOver)

# %% [markdown]
# # Simulation

# %% [markdown]
# ## Parameters from Specification

# %% [markdown]
# The time required for driving is based on the distance between way points at an average speed of 15km/h.

# %%
AVERAGE_SPEED = 15/3.6

# %% [markdown]
# The **cumulative preparation time** (route planning and
# sorting of the parcels in the delivery order and
# packing the cargo-bike) is assumed to be 50 sec per
# parcel to be delivered.

# %%
PREP_TIME_PER_PARCEL = 50

# %% [markdown]
# **Additional assumption:** The time to **process returned parcels** in the delivery centre is 30 sec per parce.

# %%
RETURN_TIME_PER_PARCEL = 30

# %% [markdown]
# The average time to answer the door.

# %%
AVERAGE_TIME_ANSWER_DOOR = 40

# %%
WAIT_TIME_IF_CUSTOMER_DOESNT_ANSWER_DOOR = 60

# %% [markdown]
# Payment of a driver per hour with a minimum of 60€ per working day

# %%
HOURLY_RATE=30

# %%
MINIMUM_WORKING_DAY= 60

# %% [markdown]
# The operational Cost (electricity and maintenance) of the electric cargo bike is 8 c/Km

# %%
OPERATIONAL_COST= 0.08

# %% [markdown]
# ## Generate Input Data

# %%
def generateDeliveryData(p, C, days, seed=0):
    ## p is the average number of parcels per day per customer
    ## C is the number of customers to be served
    ## days is the number of days for which data are to be generated.
    np.random.seed(seed)
    R = np.random.poisson(lam=len(C)*p, size=days)
    D = [ sorted(list(np.random.choice(range(len(C)), size=i))) for i in R ]
    return D

# %%
def generateInputData(D, log=False):

    R = [ len(d) for d in D ]
    N = sum(R)

    DAY_LENGTH = 24*3600    # measured in minutes
    DAY_START = 8*3600      # first delivery in the morning
    DAY_END = 17*3600     # last delivery during day time

    x = pd.DataFrame()

    x['iarr'] = [None]*N
    x['time'] = [None]*N
    x['day'] = [None]*N
    x['dest'] = [None]*N

    current_day = 0
    last_time = 0
    i = 0

    for d in D: # for each day

        if log:
            print("generating for day: ",current_day, D[current_day])

        time = current_day*DAY_LENGTH + DAY_START

        for c in d: # for each customer that should get a

            IARR = (DAY_END-DAY_START-2*3600) / len(d)  # estimated average IAT for the current day

            iat = random.expovariate(1.0/IARR)
            new_time = time + iat

            x.at[i, 'iarr'] = round(new_time - last_time,1)
            x.at[i, 'time'] = round(new_time - current_day*DAY_LENGTH , 1)
            x.at[i, 'day'] = current_day
            x.at[i, 'dest'] = c

            i += 1
            last_time = time = new_time

        current_day += 1

    return x

# %% [markdown]
# ## Simulation Routine

# %%
def simulation(M, W, C, p=0.2, days=10, title=None,
               seed=0, log=False, plot=False, timing=False):

    if timing:
        start_time = time.time()

    random.seed(seed)
    D = generateDeliveryData(p, C, days, seed)
    X = generateInputData(D, log=log)

    env = simpy.Environment()
    rec = Recorder(env, M, W, C, days, log=log, plot=plot, timing=timing)

    if title is not None:
        print(title)
    else:
        print(f"Simulating delivery of {len(X):d} parcels "
              f"over {len(D):d} days to {len(C):d} customers")

    for c in C:
        Customer.getCustomer(rec, c)
    DC = DeliveryCentre(rec, M, W)
    D = Driver(rec, DC)

    def generatorProcess(env):
        # generate the parcels based on input data x
        for i in range(len(X)):
            yield env.timeout(X.at[i, 'iarr'])
            custIndex = X.at[i, 'dest']
            custLoc = C[custIndex]
            cust = Customer.getCustomer(rec, custLoc)
            p = Parcel.getParcel(rec, i, cust, custIndex)
            DC.acceptParcel(p)

    env.process(generatorProcess(env))
    env.run()

    if log:
        print(f"Delivery Centre Inventory: {DC.getInventory():d} parcels")
    rec.finish()
    return rec

# %% [markdown]
# ## Simulation

# %%
import pickle
with open('data.pickled', 'rb') as f:
    M, C = pickle.load(f)

# %%
plotMap(M, T=C, P=[], W=W, text="seed=7635")

# %%
W
# Out:
# (1760, 4000)

# %%
random.seed(7635)
W = generateWarehouseLocation(M)
rec = simulation(M, W, C, p=0.15, days=50, plot=True, log=True, timing=True)
with open('rec.pickle', 'wb') as f:
            pickle.dump(rec, f)
# Out:
# generating for day:  0 [3, 11, 13, 18, 24, 31, 35, 40, 41, 43, 44, 67, 70, 71, 79, 83, 93, 104, 111, 118, 121, 125, 129]
# generating for day:  1 [2, 3, 9, 11, 27, 29, 31, 32, 35, 39, 41, 46, 51, 53, 67, 73, 104, 108, 111, 125, 131, 137, 138, 148]
# generating for day:  2 [0, 27, 33, 34, 34, 35, 36, 44, 61, 80, 85, 88, 91, 97, 112, 120, 126, 129, 133, 136, 138]
# generating for day:  3 [2, 17, 25, 29, 30, 33, 35, 36, 44, 66, 67, 69, 84, 91, 101, 103, 111, 114, 116, 117, 140, 146]
# generating for day:  4 [13, 16, 18, 24, 28, 39, 41, 43, 51, 58, 63, 72, 73, 81, 83, 85, 87, 87, 89, 91, 92, 93, 93, 94, 105, 106, 116, 116, 120, 123, 128, 136, 145, 147, 149]
# generating for day:  5 [0, 4, 5, 14, 18, 20, 22, 25, 26, 28, 32, 34, 51, 52, 61, 64, 68, 74, 83, 92, 105, 117, 122, 135, 136, 139, 141]
# generating for day:  46 [5, 17, 17, 22, 27, 29, 45, 48, 51, 59, 61, 61, 62, 63, 71, 76, 80, 102, 106, 106, 119, 130, 133, 137, 143, 144, 147]
# generating for day:  47 [4, 10, 28, 29, 29, 32, 43, 51, 52, 56, 59, 60, 61, 81, 84, 86, 87, 104, 109, 119, 120, 123, 125, 133, 133, 135, 142, 142, 143]
# generating for day:  48 [2, 7, 14, 17, 17, 26, 46, 55, 56, 56, 61, 72, 72, 73, 73, 81, 85, 87, 88, 93, 94, 97, 101, 108, 108, 120, 120, 122, 143]
# generating for day:  49 [12, 26, 31, 36, 49, 51, 71, 78, 83, 89, 91, 94, 96, 98, 102, 109, 111, 111, 121, 127, 131, 132, 146, 146, 146, 148]
# Simulating delivery of 1139 parcels over 50 days to 150 customers
# [ 0] 08:33:58.5 Parcel:   0 (  3) arr at delivery centre
# ==== t:   0.00s Δt:   0.00s [addTarget]
# createTables:     0.09s
# createLoopH:      0.09s
# ==== t:   0.09s Δt:   0.09s [createLoopH]
# [ 0] 08:59:52.8 Parcel:   1 ( 11) arr at delivery centre
# ==== t:   0.09s Δt:   0.00s [addTarget]
# createTables:     0.08s
# createLoopH:      0.08s
# ==== t:   0.18s Δt:   0.09s [createLoopH]
# [ 0] 09:09:50.7 Parcel:   2 ( 13) arr at delivery centre
# ==== t:   0.18s Δt:   0.00s [addTarget]
# createTables:     0.09s
# createLoopH:      0.09s
# ==== t:   0.27s Δt:   0.09s [createLoopH]
# [ 0] 09:15:19.0 Parcel:   3 ( 18) arr at delivery centre
# ==== t:   0.27s Δt:   0.00s [addTarget]
# createTables:     0.10s
# createLoopH:      0.10s
# ==== t:   0.37s Δt:   0.10s [createLoopH]
# [ 0] 09:28:23.5 Parcel:   4 ( 24) arr at delivery centre
# ==== t:   0.37s Δt:   0.00s [addTarget]
# createTables:     0.10s
# createLoopH:      0.10s
# ==== t:   0.46s Δt:   0.10s [createLoopH]
# [ 0] 09:37:52.1 Parcel:   5 ( 31) arr at delivery centre
# ==== t:   0.46s Δt:   0.00s [addTarget]
# createTables:     0.09s
# createLoopH:      0.09s
# ==== t:   0.56s Δt:   0.09s [createLoopH]
# [ 0] 10:05:50.1 Parcel:   6 ( 35) arr at delivery centre
# ==== t:   0.56s Δt:   0.00s [addTarget]
# createTables:     0.10s
# createLoopH:      0.10s
# ==== t:   0.65s Δt:   0.10s [createLoopH]
# [ 0] 10:12:26.1 Parcel:   7 ( 40) arr at delivery centre
# ==== t:   0.66s Δt:   0.00s [addTarget]
# createTables:     0.10s
# createLoopH:      0.10s
# ==== t:   0.75s Δt:   0.10s [createLoopH]
# [ 0] 10:24:15.5 Parcel:   8 ( 41) arr at delivery centre
# ==== t:   0.75s Δt:   0.00s [addTarget]
# createTables:     0.10s
# createLoopH:      0.10s
# ==== t:   0.85s Δt:   0.10s [createLoopH]
# [ 0] 10:40:14.8 Parcel:   9 ( 43) arr at delivery centre
# ==== t:   0.85s Δt:   0.00s [addTarget]
# createTables:     0.11s
# createLoopH:      0.11s
# ==== t:   0.96s Δt:   0.11s [createLoopH]
# [ 0] 11:23:50.3 Parcel:  10 ( 44) arr at delivery centre
# ==== t:   0.96s Δt:   0.00s [addTarget]
# createTables:     0.11s
# createLoopH:      0.11s
# ==== t:   1.08s Δt:   0.11s [createLoopH]
# [ 0] 11:36:40.1 Parcel:  11 ( 67) arr at delivery centre
# ==== t:   1.08s Δt:   0.00s [addTarget]
# createTables:     0.12s
# createLoopH:      0.12s
# ==== t:   1.20s Δt:   0.12s [createLoopH]
# [ 0] 11:42:42.8 Parcel:  12 ( 70) arr at delivery centre
# ==== t:   1.20s Δt:   0.00s [addTarget]
# createTables:     0.12s
# createLoopH:      0.12s
# ==== t:   1.32s Δt:   0.12s [createLoopH]
# [ 0] 12:08:27.4 Parcel:  13 ( 71) arr at delivery centre
# ==== t:   1.32s Δt:   0.00s [addTarget]
# createTables:     0.12s
# createLoopH:      0.12s
# ==== t:   1.44s Δt:   0.12s [createLoopH]
# [ 0] 12:26:02.8 Parcel:  14 ( 79) arr at delivery centre
# ==== t:   1.44s Δt:   0.00s [addTarget]
# createTables:     0.13s
# createLoopH:      0.13s
# ==== t:   1.57s Δt:   0.13s [createLoopH]
# [ 0] 12:31:18.7 Parcel:  15 ( 83) arr at delivery centre
# ==== t:   1.58s Δt:   0.00s [addTarget]
# createTables:     0.31s
# createLoopH:      0.31s
# ==== t:   1.89s Δt:   0.32s [createLoopH]
# [ 0] 13:15:13.9 Parcel:  16 ( 93) arr at delivery centre
# ==== t:   1.90s Δt:   0.00s [addTarget]
# createTables:     0.15s
# createLoopH:      0.15s
# ==== t:   2.05s Δt:   0.15s [createLoopH]
# [ 0] 14:29:24.4 Parcel:  17 (104) arr at delivery centre
# ==== t:   2.05s Δt:   0.00s [addTarget]
# createTables:     0.13s
# createLoopH:      0.13s
# ==== t:   2.18s Δt:   0.13s [createLoopH]
# [ 0] 14:59:45.2 Parcel:  18 (111) arr at delivery centre
# ==== t:   2.19s Δt:   0.00s [addTarget]
# createTables:     0.14s
# createLoopH:      0.14s
# ==== t:   2.33s Δt:   0.14s [createLoopH]
# createTables:     0.17s
# Solver:           0.13s    420 Constraints
# Solver:           0.13s    423 Constraints
# Solver:           0.22s    426 Constraints
# Solver:           0.22s    427 Constraints
# Solver:           0.29s    429 Constraints
# Solver:           0.30s    431 Constraints
# createLoop:       1.45s
# ==== t:   3.78s Δt:   1.45s [createLoop]
# [ 0] 15:42:12.0 Parcel:  19 (118) arr at delivery centre
# ==== t:   3.78s Δt:   0.00s [addTarget]
# createTables:     0.13s
# createLoopH:      0.14s
# ==== t:   3.92s Δt:   0.14s [createLoopH]
# createTables:     0.18s
# Solver:           0.11s    462 Constraints
# Solver:           0.11s    465 Constraints
# Solver:           0.14s    468 Constraints
# Solver:           0.14s    469 Constraints
# createLoop:       0.68s
# ==== t:   4.60s Δt:   0.68s [createLoop]
# [ 0] 15:48:58.8 Parcel:  20 (121) arr at delivery centre
# ==== t:   4.60s Δt:   0.00s [addTarget]
# createTables:     0.15s
# createLoopH:      0.16s
# ==== t:   4.76s Δt:   0.16s [createLoopH]
# createTables:     0.23s
# Solver:           0.12s    506 Constraints
# Solver:           0.12s    509 Constraints
# Solver:           0.16s    512 Constraints
# Solver:           0.13s    513 Constraints
# Solver:           0.17s    517 Constraints
# Solver:           0.22s    520 Constraints
# Solver:           0.24s    521 Constraints
# Solver:           0.31s    522 Constraints
# createLoop:       1.71s
# ==== t:   6.47s Δt:   1.71s [createLoop]
# [ 0] 16:12:52.7 Parcel:  21 (125) arr at delivery centre
# ==== t:   6.47s Δt:   0.00s [addTarget]
# createTables:     0.15s
# createLoopH:      0.16s
# ==== t:   6.63s Δt:   0.16s [createLoopH]
# createTables:     0.22s
# Solver:           0.10s    506 Constraints
# Solver:           0.13s    511 Constraints
# Solver:           0.15s    514 Constraints
# createLoop:       0.60s
# ==== t:   7.23s Δt:   0.60s [createLoop]
# [ 0] 16:54:42.9 Parcel:  22 (129) arr at delivery centre
# ==== t:   7.23s Δt:   0.00s [addTarget]
# createTables:     0.15s
# createLoopH:      0.16s
# ==== t:   7.39s Δt:   0.16s [createLoopH]
# createTables:     0.28s
# Solver:           0.09s    552 Constraints
# Solver:           0.14s    556 Constraints
# Solver:           0.14s    559 Constraints
# Solver:           0.15s    560 Constraints
# createLoop:       0.80s
# ==== t:   8.19s Δt:   0.80s [createLoop]
# [ 0] 18:00:00.0 Driver arrives for work
# [ 0] 18:00:00.0 Parcel:   2 ( 13) out for delivery
# [ 0] 18:00:00.0 Parcel:   0 (  3) out for delivery
# [ 0] 18:00:00.0 Parcel:   1 ( 11) out for delivery
# [ 0] 18:00:00.0 Parcel:   3 ( 18) out for delivery
# [ 0] 18:00:00.0 Parcel:   9 ( 43) out for delivery
# [ 0] 18:00:00.0 Parcel:   6 ( 35) out for delivery
# [ 0] 18:00:00.0 Parcel:   7 ( 40) out for delivery
# [ 0] 18:00:00.0 Parcel:   8 ( 41) out for delivery
# [ 0] 18:00:00.0 Parcel:  11 ( 67) out for delivery
# [ 0] 18:00:00.0 Parcel:  14 ( 79) out for delivery
# [ 0] 18:00:00.0 Parcel:  16 ( 93) out for delivery
# [ 0] 18:00:00.0 Parcel:  18 (111) out for delivery
# [ 0] 18:00:00.0 Parcel:  19 (118) out for delivery
# [ 0] 18:00:00.0 Parcel:  21 (125) out for delivery
# [ 0] 18:00:00.0 Parcel:  17 (104) out for delivery
# [ 0] 18:00:00.0 Parcel:  15 ( 83) out for delivery
# [ 0] 18:00:00.0 Parcel:  12 ( 70) out for delivery
# [ 0] 18:00:00.0 Parcel:  13 ( 71) out for delivery
# [ 0] 18:00:00.0 Parcel:  10 ( 44) out for delivery
# [ 0] 18:00:00.0 Parcel:   5 ( 31) out for delivery
# [ 0] 18:00:00.0 Parcel:   4 ( 24) out for delivery
# ==== t:   8.19s Δt:   0.00s [addTarget]
# createTables:     0.08s
# createLoopH:      0.08s
# ==== t:   8.28s Δt:   0.09s [createLoopH]
# ==== t:   8.28s Δt:   0.00s [addTarget]
# createTables:     0.09s
# createLoopH:      0.09s
# ==== t:   8.37s Δt:   0.09s [createLoopH]
# [ 0] 18:17:30.0 Driver leaves for delivery of 21 parcels
# [ 0] 18:17:30.0 Driver drives to Customer: 13 (1008, 3440)
# [ 0] 18:22:44.8 Driver arrived at Customer: 13 (1008, 3440)
# [ 0] 18:22:46.4 Customer: 13 (1008, 3440) answers door
# [ 0] 18:22:46.4 Customer: 13 (1008, 3440) accepts Parcel:   2 ( 13)
# [ 0] 18:22:55.2 Customer: 13 (1008, 3440) signs off
# [ 0] 18:23:05.5 Driver drives to Customer:  3 (640, 3632)
# [ 0] 18:25:19.9 Driver arrived at Customer:  3 (640, 3632)
# [ 0] 18:25:21.2 Customer:  3 (640, 3632) answers door
# [ 0] 18:25:21.2 Customer:  3 (640, 3632) accepts Parcel:   0 (  3)
# [ 0] 18:25:35.4 Customer:  3 (640, 3632) signs off
# [ 0] 18:25:52.4 Driver drives to Customer: 11 (965, 5680)
# [ 0] 18:35:22.0 Driver arrived at Customer: 11 (965, 5680)
# [ 0] 18:35:24.9 Customer: 11 (965, 5680) answers door
# [ 0] 20:33:43.7 Customer: 44 (2528, 640) signs off
# [ 0] 20:33:48.7 Driver drives to Customer: 31 (2126, 3633)
# [ 0] 20:49:45.1 Driver arrived at Customer: 31 (2126, 3633)
# [ 0] 20:50:02.8 Customer: 31 (2126, 3633) answers door
# [ 0] 20:50:02.8 Customer: 31 (2126, 3633) accepts Parcel:   5 ( 31)
# [ 0] 20:50:04.1 Customer: 31 (2126, 3633) signs off
# [ 0] 20:50:08.4 Driver drives to Customer: 24 (1935, 3824)
# [ 0] 20:51:13.2 Driver arrived at Customer: 24 (1935, 3824)
# [ 0] 20:51:21.0 Customer: 24 (1935, 3824) answers door
# [ 0] 20:51:21.0 Customer: 24 (1935, 3824) accepts Parcel:   4 ( 24)
# [ 0] 20:51:30.6 Customer: 24 (1935, 3824) signs off
# [ 0] 20:51:41.2 Driver returns to delivery centre
# [ 0] 20:52:40.7 Driver arrived at delivery centre
# [ 0] 21:02:40.7 2 left over for next day
# [ 0] 21:02:40.7 Driver goes home
# [ 1] 08:20:09.2 Parcel:  23 (  2) arr at delivery centre
# ==== t:   8.46s Δt:   0.09s [addTarget]
# createTables:     0.11s
# createLoopH:      0.11s
# ==== t:   8.57s Δt:   0.11s [createLoopH]
# [ 1] 08:31:20.1 Parcel:  24 (  3) arr at delivery centre
# ==== t:   8.57s Δt:   0.00s [addTarget]
# createTables:     0.08s
# createLoopH:      0.08s
# ==== t:   8.65s Δt:   0.09s [createLoopH]
# [ 1] 08:33:11.5 Parcel:  25 (  9) arr at delivery centre
# ==== t:   8.65s Δt:   0.00s [addTarget]
# createTables:     0.10s
# createLoopH:      0.10s
# ==== t:   8.75s Δt:   0.10s [createLoopH]
# [ 1] 08:43:09.3 Parcel:  26 ( 11) arr at delivery centre
# ==== t:   8.75s Δt:   0.00s [addTarget]
# createTables:     0.09s
# createLoopH:      0.09s
# ==== t:   8.84s Δt:   0.09s [createLoopH]
# [ 1] 08:59:40.5 Parcel:  27 ( 27) arr at delivery centre
# ==== t:   8.84s Δt:   0.00s [addTarget]
# createTables:     0.10s
# createLoopH:      0.10s
# ==== t:   8.95s Δt:   0.10s [createLoopH]
# [ 1] 09:42:24.6 Parcel:  28 ( 29) arr at delivery centre
# ==== t:   8.95s Δt:   0.00s [addTarget]
# createTables:     0.10s
# createLoopH:      0.10s
# ==== t:   9.06s Δt:   0.10s [createLoopH]
# [ 1] 10:41:54.0 Parcel:  29 ( 31) arr at delivery centre
# ==== t:   9.06s Δt:   0.00s [addTarget]
# createTables:     0.24s
# createLoopH:      0.24s
# ==== t:   9.30s Δt:   0.24s [createLoopH]
# [ 1] 10:53:14.6 Parcel:  30 ( 32) arr at delivery centre
# ==== t:   9.30s Δt:   0.00s [addTarget]
# createTables:     0.11s
# createLoopH:      0.11s
# ==== t:   9.41s Δt:   0.11s [createLoopH]
# [ 1] 11:28:19.6 Parcel:  31 ( 35) arr at delivery centre
# ==== t:   9.42s Δt:   0.00s [addTarget]
# createTables:     0.11s
# createLoopH:      0.11s
# ==== t:   9.53s Δt:   0.11s [createLoopH]
# [ 1] 11:33:36.5 Parcel:  32 ( 39) arr at delivery centre
# ==== t:   9.53s Δt:   0.00s [addTarget]
# createTables:     0.11s
# createLoopH:      0.11s
# ==== t:   9.65s Δt:   0.11s [createLoopH]
# [ 1] 12:02:13.1 Parcel:  33 ( 41) arr at delivery centre
# ==== t:   9.65s Δt:   0.00s [addTarget]
# createTables:     0.12s
# createLoopH:      0.12s
# ==== t:   9.77s Δt:   0.12s [createLoopH]
# [ 1] 12:16:08.5 Parcel:  34 ( 46) arr at delivery centre
# ==== t:   9.77s Δt:   0.00s [addTarget]
# createTables:     0.12s
# createLoopH:      0.13s
# ==== t:   9.90s Δt:   0.13s [createLoopH]
# [ 1] 12:16:23.3 Parcel:  35 ( 51) arr at delivery centre
# ==== t:   9.90s Δt:   0.00s [addTarget]
# createTables:     0.13s
# createLoopH:      0.13s
# ==== t:  10.03s Δt:   0.13s [createLoopH]
# [ 1] 12:38:38.7 Parcel:  36 ( 53) arr at delivery centre
# ==== t:  10.03s Δt:   0.00s [addTarget]
# createTables:     0.12s
# createLoopH:      0.12s
# ==== t:  10.15s Δt:   0.12s [createLoopH]
# [ 1] 12:47:33.0 Parcel:  37 ( 67) arr at delivery centre
# ==== t:  10.16s Δt:   0.00s [addTarget]
# createTables:     0.13s
# createLoopH:      0.13s
# ==== t:  10.29s Δt:   0.13s [createLoopH]
# [ 1] 13:18:02.2 Parcel:  38 ( 73) arr at delivery centre
# ==== t:  10.29s Δt:   0.00s [addTarget]
# createTables:     0.13s
# createLoopH:      0.13s
# ==== t:  10.43s Δt:   0.14s [createLoopH]
# createTables:     0.10s
# Solver:           0.11s    380 Constraints
# Solver:           0.13s    382 Constraints
# Solver:           0.12s    383 Constraints
# createLoop:       0.47s
# ==== t:  10.89s Δt:   0.47s [createLoop]
# [ 1] 13:37:20.5 Parcel:  39 (104) arr at delivery centre
# ==== t:  10.90s Δt:   0.00s [addTarget]
# createTables:     0.13s
# createLoopH:      0.13s
# ==== t:  11.03s Δt:   0.13s [createLoopH]
# createTables:     0.14s
# Solver:           0.11s    420 Constraints
# Solver:           0.11s    424 Constraints
# Solver:           0.12s    425 Constraints
# createLoop:       0.48s
# ==== t:  11.51s Δt:   0.48s [createLoop]
# [ 1] 13:37:21.7 Parcel:  40 (108) arr at delivery centre
# ==== t:  11.51s Δt:   0.00s [addTarget]
# createTables:     0.14s
# createLoopH:      0.15s
# ==== t:  11.66s Δt:   0.15s [createLoopH]
# createTables:     0.30s
# Solver:           0.09s    462 Constraints
# Solver:           0.18s    464 Constraints
# Solver:           0.14s    465 Constraints
# createLoop:       0.70s
# ==== t:  12.36s Δt:   0.70s [createLoop]
# [ 1] 13:49:16.1 Parcel:  41 (111) arr at delivery centre
# ==== t:  12.36s Δt:   0.00s [addTarget]
# createTables:     0.14s
# createLoopH:      0.14s
# ==== t:  12.51s Δt:   0.14s [createLoopH]
# createTables:     0.20s
# Solver:           0.12s    462 Constraints
# Solver:           0.20s    464 Constraints
# Solver:           0.13s    465 Constraints
# createLoop:       0.65s
# ==== t:  13.16s Δt:   0.65s [createLoop]
# [ 1] 14:24:39.1 Parcel:  42 (125) arr at delivery centre
# ==== t:  13.16s Δt:   0.00s [addTarget]
# createTables:     0.14s
# createLoopH:      0.14s
# ==== t:  13.31s Δt:   0.14s [createLoopH]
# createTables:     0.24s
# Solver:           0.21s    506 Constraints
# Solver:           0.15s    508 Constraints
# Solver:           0.17s    509 Constraints
# createLoop:       0.76s
# ==== t:  14.07s Δt:   0.77s [createLoop]
# [ 1] 14:29:32.7 Parcel:  43 (131) arr at delivery centre
# ==== t:  14.08s Δt:   0.00s [addTarget]
# createTables:     0.14s
# createLoopH:      0.15s
# ==== t:  14.23s Δt:   0.15s [createLoopH]
# createTables:     0.27s
# Solver:           0.10s    552 Constraints
# Solver:           0.13s    557 Constraints
# Solver:           0.14s    558 Constraints
# createLoop:       0.65s
# ==== t:  14.87s Δt:   0.65s [createLoop]
# [ 1] 14:36:25.7 Parcel:  44 (137) arr at delivery centre
# ==== t:  14.88s Δt:   0.00s [addTarget]
# createTables:     0.17s
# createLoopH:      0.18s
# ==== t:  15.06s Δt:   0.18s [createLoopH]
# createTables:     0.27s
# Solver:           0.11s    600 Constraints
# Solver:           0.12s    605 Constraints
# Solver:           0.14s    606 Constraints
# createLoop:       0.64s
# ==== t:  15.69s Δt:   0.64s [createLoop]
# [ 1] 15:12:11.7 Parcel:  45 (138) arr at delivery centre
# ==== t:  15.70s Δt:   0.00s [addTarget]
# createTables:     0.28s
# createLoopH:      0.28s
# ==== t:  15.98s Δt:   0.29s [createLoopH]
# createTables:     0.26s
# Solver:           0.12s    650 Constraints
# Solver:           0.18s    655 Constraints
# Solver:           0.21s    656 Constraints
# createLoop:       0.77s
# ==== t:  16.75s Δt:   0.77s [createLoop]
# [ 1] 15:15:54.3 Parcel:  46 (148) arr at delivery centre
# ==== t:  16.75s Δt:   0.00s [addTarget]
# createTables:     0.17s
# createLoopH:      0.18s
# ==== t:  16.93s Δt:   0.18s [createLoopH]
# createTables:     0.33s
# Solver:           0.12s    702 Constraints
# Solver:           0.20s    707 Constraints
# Solver:           0.20s    708 Constraints
# createLoop:       0.85s
# ==== t:  17.78s Δt:   0.85s [createLoop]
# [ 1] 18:00:00.0 Driver arrives for work
# [ 1] 18:00:00.0 Parcel:  26 ( 11) out for delivery
# [ 1] 18:00:00.0 Parcel:  31 ( 35) out for delivery
# [ 1] 18:00:00.0 Parcel:  27 ( 27) out for delivery
# [ 1] 18:00:00.0 Parcel:  32 ( 39) out for delivery
# [ 1] 18:00:00.0 Parcel:  33 ( 41) out for delivery
# [ 1] 18:00:00.0 Parcel:  36 ( 53) out for delivery
# [ 1] 18:00:00.0 Parcel:  34 ( 46) out for delivery
# [ 1] 18:00:00.0 Parcel:  37 ( 67) out for delivery
# [ 1] 18:00:00.0 Parcel:  38 ( 73) out for delivery
# [ 1] 18:00:00.0 Parcel:  41 (111) out for delivery
# [ 1] 18:00:00.0 Parcel:  22 (129) out for delivery
# [ 1] 18:00:00.0 Parcel:  45 (138) out for delivery
# [ 1] 18:00:00.0 Parcel:  44 (137) out for delivery
# [ 1] 18:00:00.0 Parcel:  43 (131) out for delivery
# [ 1] 18:00:00.0 Parcel:  42 (125) out for delivery
# [ 1] 18:00:00.0 Parcel:  20 (121) out for delivery
# [ 1] 18:00:00.0 Parcel:  39 (104) out for delivery
# [ 1] 18:00:00.0 Parcel:  35 ( 51) out for delivery
# [ 1] 18:00:00.0 Parcel:  30 ( 32) out for delivery
# [ 1] 18:00:00.0 Parcel:  28 ( 29) out for delivery
# [ 1] 18:00:00.0 Parcel:  25 (  9) out for delivery
# [ 1] 18:00:00.0 Parcel:  23 (  2) out for delivery
# [ 1] 18:00:00.0 Parcel:  24 (  3) out for delivery
# [ 1] 18:00:00.0 Parcel:  29 ( 31) out for delivery
# ==== t:  17.78s Δt:   0.00s [addTarget]
# createTables:     0.09s
# createLoopH:      0.09s
# ==== t:  17.86s Δt:   0.09s [createLoopH]
# ==== t:  17.86s Δt:   0.00s [addTarget]
# createTables:     0.09s
# createLoopH:      0.09s
# ====
[addTarget]
# createTables:     0.09s
# createLoopH:      0.09s
# ==== t:  18.13s Δt:   0.09s [createLoopH]
# [ 2] 08:22:12.4 Parcel:  48 ( 27) arr at delivery centre
# ==== t:  18.13s Δt:   0.00s [addTarget]
# createTables:     0.09s
# createLoopH:      0.09s
# ==== t:  18.23s Δt:   0.09s [createLoopH]
# [ 2] 09:30:45.7 Parcel:  49 ( 33) arr at delivery centre
# ==== t:  18.23s Δt:   0.00s [addTarget]
# createTables:     0.09s
# createLoopH:      0.09s
# ==== t:  18.32s Δt:   0.09s [createLoopH]
# [ 2] 10:03:16.3 Parcel:  50 ( 34) arr at delivery centre
# ==== t:  18.32s Δt:   0.00s [addTarget]
# createTables:     0.10s
# createLoopH:      0.10s
# ==== t:  18.42s Δt:   0.10s [createLoopH]
# [ 2] 10:15:09.3 Parcel:  51 ( 34) arr at delivery centre
# [ 2] 10:16:49.9 Parcel:  52 ( 35) arr at delivery centre
# ==== t:  18.43s Δt:   0.00s [addTarget]
# createTables:     0.10s
# createLoopH:      0.10s
# ==== t:  18.53s Δt:   0.10s [createLoopH]
# [ 2] 10:24:32.8 Parcel:  53 ( 36) arr at delivery centre
# ==== t:  18.53s Δt:   0.00s [addTarget]
# createTables:     0.10s
# createLoopH:      0.10s
# ==== t:  18.63s Δt:   0.10s [createLoopH]
# [ 2] 10:38:43.8 Parcel:  54 ( 44) arr at delivery centre
# ==== t:  18.63s Δt:   0.00s [addTarget]
# createTables:     0.10s
# createLoopH:      0.10s
# ==== t:  18.73s Δt:   0.10s [createLoopH]
# [ 2] 11:32:44.5 Parcel:  55 ( 61) arr at delivery centre
# ==== t:  18.73s Δt:   0.00s [addTarget]
# createTables:     0.11s
# createLoopH:      0.11s
# ==== t:  18.84s Δt:   0.11s [createLoopH]
# [ 2] 11:35:03.1 Parcel:  56 ( 80) arr at delivery centre
# ==== t:  18.84s Δt:   0.00s [addTarget]
# createTables:     0.11s
# createLoopH:      0.11s
# ==== t:  18.95s Δt:   0.11s [createLoopH]
# [ 2] 11:51:04.7 Parcel:  57 ( 85) arr at delivery centre
# ==== t:  18.96s Δt:   0.00s [addTarget]
# createTables:     0.12s
# createLoopH:      0.12s
# ==== t:  19.08s Δt:   0.12s [createLoopH]
# [ 2] 12:15:36.0 Parcel:  58 ( 88) arr at delivery centre
# ==== t:  19.08s Δt:   0.00s [addTarget]
# createTables:     0.11s
# createLoopH:      0.11s
# ==== t:  19.20s Δt:   0.12s [createLoopH]
# [ 2] 12:31:27.4 Parcel:  59 ( 91) arr at delivery centre
# ==== t:  19.20s Δt:   0.00s [addTarget]
# createTables:     0.12s
# createLoopH:      0.12s
# ==== t:  19.32s Δt:   0.12s [createLoopH]
# [ 2] 13:05:08.8 Parcel:  60 ( 97) arr at delivery centre
# ==== t:  19.32s Δt:   0.00s [addTarget]
# createTables:     0.12s
# createLoopH:      0.12s
# ==== t:  19.45s Δt:   0.12s [createLoopH]
# [ 2] 13:20:41.4 Parcel:  61 (112) arr at delivery centre
# ==== t:  19.45s Δt:   0.00s [addTarget]
# createTables:     0.26s
# createLoopH:      0.26s
# ==== t:  19.71s Δt:   0.26s [createLoopH]
# [ 2] 14:27:05.1 Parcel:  62 (120) arr at delivery centre
# ==== t:  19.71s Δt:   0.00s [addTarget]
# createTables:     0.13s
# createLoopH:      0.13s
# ==== t:  19.84s Δt:   0.13s [createLoopH]
# createTables:     0.14s
# Solver:           0.12s    342 Constraints
# createLoop:       0.26s
# ==== t:  20.10s Δt:   0.26s [createLoop]
# [ 2] 14:45:34.2 Parcel:  63 (126) arr at delivery centre
# ==== t:  20.10s Δt:   0.00s [addTarget]
# createTables:     0.13s
# createLoopH:      0.14s
# ==== t:  20.24s Δt:   0.14s [createLoopH]
# createTables:     0.19s
# Solver:           0.09s    380 Constraints
# Solver:           0.11s    381 Constraints
# createLoop:       0.39s
# ==== t:  20.63s Δt:   0.39s [createLoop]
# [ 2] 15:03:17.2 Parcel:  64 (129) arr at delivery centre
# ==== t:  20.63s Δt:   0.00s [addTarget]
# createTables:     0.13s
# createLoopH:      0.14s
# ==== t:  20.77s Δt:   0.14s [createLoopH]
# createTables:     0.18s
# Solver:           0.09s    420 Constraints
# Solver:           0.09s    421 Constraints
# Solver:           0.12s    422 Constraints
# createLoop:       0.49s
# ==== t:  21.25s Δt:   0.49s [createLoop]
# [ 2] 15:15:03.7 Parcel:  65 (133) arr at delivery centre
# ==== t:  21.26s Δt:   0.00s [addTarget]
# createTables:     0.14s
# createLoopH:      0.14s
# ==== t:  21.40s Δt:   0.14s [createLoopH]
# createTables:     0.19s
# Solver:           0.10s    462 Constraints
# Solver:           0.08s    463 Constraints
# Solver:           0.15s    464 Constraints
# createLoop:       0.52s
# ==== t:  21.92s Δt:   0.52s [createLoop]
# [ 2] 15:33:12.2 Parcel:  66 (136) arr at delivery centre
# ==== t:  21.92s Δt:   0.00s [addTarget]
# createTables:     0.14s
# createLoopH:      0.15s
# ==== t:  22.07s Δt:   0.15s [createLoopH]
# createTables:     0.22s
# Solver:           0.10s    506 Constraints
# Solver:           0.10s    508 Constraints
# Solver:           0.14s    509 Constraints
# createLoop:       0.56s
# ==== t:  22.63s Δt:   0.56s [createLoop]
# [ 2] 15:42:55.4 Parcel:  67 (138) arr at delivery centre
# ==== t:  22.64s Δt:   0.00s [addTarget]
# createTables:     0.14s
# createLoopH:      0.15s
# ==== t:  22.79s Δt:   0.15s [createLoopH]
# createTables:     0.23s
# Solver:           0.12s    552 Constraints
# createLoop:       0.35s
# ==== t:  23.13s Δt:   0.35s [createLoop]
# [ 2] 18:00:00.0 Driver arrives for work
# [ 2] 18:00:00.0 Parcel:  47 (  0) out for delivery
# [ 2] 18:00:00.0 Parcel:  54 ( 44) out for delivery
# [ 2] 18:00:00.0 Parcel:  57 ( 85) out for delivery
# [ 2] 18:00:00.0 Parcel:  56 ( 80) out for delivery
# [ 2] 18:00:00.0 Parcel:  59 ( 91) out for delivery
# [ 2] 18:00:00.0 Parcel:  60 ( 97) out for delivery
# [ 2] 18:00:00.0 Parcel:  62 (120) out for delivery
# [ 2] 18:00:00.0 Parcel:  46 (148) out for delivery
# [ 2] 18:00:00.0 Parcel:  65 (133) out for delivery
# [ 2] 18:00:00.0 Parcel:  66 (136) out for delivery
# [ 2] 18:00:00.0 Parcel:  67 (138) out for delivery
# [ 2] 18:00:00.0 Parcel:  64 (129) out for delivery
# [ 2] 18:00:00.0 Parcel:  63 (126) out for delivery
# [ 2] 18:00:00.0 Parcel:  61 (112) out for delivery
# [ 2] 18:00:00.0 Parcel:  40 (108) out for delivery
# [ 2] 18:00:00.0 Parcel:  58 ( 88) out for delivery
# [ 2] 18:00:00.0 Parcel:  55 ( 61) out for delivery
# [ 2] 18:00:00.0 Parcel:  48 ( 27) out for delivery
# [ 2] 18:00:00.0 Parcel:  53 ( 36) out for delivery
# [ 2] 18:00:00.0 Parcel:  52 ( 35) out for delivery
# [ 2] 18:00:00.0 Parcel:  49 ( 33) out for delivery
# [ 2] 18:00:00.0 Parcel:  50 ( 34) out for delivery
[addTarget]
# createTables:     0.09s
# createLoopH:      0.09s
# ==== t: 1238.78s Δt:   0.09s [createLoopH]
# [49] 08:12:55.2 Parcel: 1114 ( 26) arr at delivery centre
# ==== t: 1238.78s Δt:   0.00s [addTarget]
# createTables:     0.10s
# createLoopH:      0.10s
# ==== t: 1238.88s Δt:   0.10s [createLoopH]
# [49] 08:29:30.5 Parcel: 1115 ( 31) arr at delivery centre
# ==== t: 1238.88s Δt:   0.00s [addTarget]
# createTables:     0.09s
# createLoopH:      0.09s
# ==== t: 1238.97s Δt:   0.10s [createLoopH]
# [49] 08:52:50.3 Parcel: 1116 ( 36) arr at delivery centre
# ==== t: 1238.98s Δt:   0.00s [addTarget]
# createTables:     0.10s
# createLoopH:      0.10s
# ==== t: 1239.08s Δt:   0.10s [createLoopH]
# [49] 08:53:36.7 Parcel: 1117 ( 49) arr at delivery centre
# ==== t: 1239.08s Δt:   0.00s [addTarget]
# createTables:     0.11s
# createLoopH:      0.11s
# ==== t: 1239.19s Δt:   0.11s [createLoopH]
# [49] 09:21:39.2 Parcel: 1118 ( 51) arr at delivery centre
# ==== t: 1239.19s Δt:   0.00s [addTarget]
# createTables:     0.11s
# createLoopH:      0.11s
# ==== t: 1239.30s Δt:   0.11s [createLoopH]
# [49] 09:22:22.3 Parcel: 1119 ( 71) arr at delivery centre
# ==== t: 1239.30s Δt:   0.00s [addTarget]
# createTables:     0.11s
# createLoopH:      0.11s
# ==== t: 1239.41s Δt:   0.11s [createLoopH]
# [49] 09:35:27.0 Parcel: 1120 ( 78) arr at delivery centre
# ==== t: 1239.41s Δt:   0.00s [addTarget]
# createTables:     0.11s
# createLoopH:      0.11s
# ==== t: 1239.52s Δt:   0.11s [createLoopH]
# [49] 09:57:28.2 Parcel: 1121 ( 83) arr at delivery centre
# ==== t: 1239.52s Δt:   0.00s [addTarget]
# createTables:     0.11s
# createLoopH:      0.12s
# ==== t: 1239.64s Δt:   0.12s [createLoopH]
# [49] 10:13:35.1 Parcel: 1122 ( 89) arr at delivery centre
# ==== t: 1239.64s Δt:   0.00s [addTarget]
# createTables:     0.13s
# createLoopH:      0.13s
# ==== t: 1239.77s Δt:   0.13s [createLoopH]
# [49] 11:01:52.4 Parcel: 1123 ( 91) arr at delivery centre
# ==== t: 1239.77s Δt:   0.00s [addTarget]
# createTables:     0.12s
# createLoopH:      0.12s
# ==== t: 1239.90s Δt:   0.12s [createLoopH]
# [49] 11:08:42.1 Parcel: 1124 ( 94) arr at delivery centre
# ==== t: 1239.90s Δt:   0.00s [addTarget]
# createTables:     0.25s
# createLoopH:      0.25s
# ==== t: 1240.15s Δt:   0.25s [createLoopH]
# [49] 11:22:56.6 Parcel: 1125 ( 96) arr at delivery centre
# ==== t: 1240.16s Δt:   0.00s [addTarget]
# createTables:     0.13s
# createLoopH:      0.13s
# ==== t: 1240.29s Δt:   0.13s [createLoopH]
# [49] 11:24:20.4 Parcel: 1126 ( 98) arr at delivery centre
# ==== t: 1240.29s Δt:   0.00s [addTarget]
# createTables:     0.14s
# createLoopH:      0.14s
# ==== t: 1240.43s Δt:   0.14s [createLoopH]
# [49] 11:37:35.7 Parcel: 1127 (102) arr at delivery centre
# ==== t: 1240.43s Δt:   0.00s [addTarget]
# createTables:     0.14s
# createLoopH:      0.14s
# ==== t: 1240.58s Δt:   0.15s [createLoopH]
# [49] 12:04:42.3 Parcel: 1128 (109) arr at delivery centre
# ==== t: 1240.58s Δt:   0.00s [addTarget]
# createTables:     0.15s
# createLoopH:      0.15s
# ==== t: 1240.73s Δt:   0.15s [createLoopH]
# [49] 12:08:20.5 Parcel: 1129 (111) arr at delivery centre
# ==== t: 1240.74s Δt:   0.00s [addTarget]
# createTables:     0.14s
# createLoopH:      0.15s
# ==== t: 1240.89s Δt:   0.15s [createLoopH]
# createTables:     0.11s
# Solver:           0.13s    462 Constraints
# Solver:           0.16s    465 Constraints
# createLoop:       0.40s
# ==== t: 1241.29s Δt:   0.40s [createLoop]
# [49] 12:13:13.6 Parcel: 1130 (111) arr at delivery centre
# ==== t: 1241.29s Δt:   0.00s [addTarget]
# createTables:     0.14s
# createLoopH:      0.14s
# ==== t: 1241.44s Δt:   0.14s [createLoopH]
# createTables:     0.10s
# Solver:           0.13s    462 Constraints
# Solver:           0.16s    465 Constraints
# createLoop:       0.39s
# ==== t: 1241.83s Δt:   0.39s [createLoop]
# [49] 12:32:41.8 Parcel: 1131 (121) arr at delivery centre
# ==== t: 1241.83s Δt:   0.00s [addTarget]
# createTables:     0.15s
# createLoopH:      0.15s
# ==== t: 1241.99s Δt:   0.15s [createLoopH]
# [49] 12:37:25.7 Parcel: 1132 (127) arr at delivery centre
# ==== t: 1241.99s Δt:   0.00s [addTarget]
# createTables:     0.14s
# createLoopH:      0.15s
# ==== t: 1242.14s Δt:   0.15s [createLoopH]
# [49] 12:42:16.6 Parcel: 1133 (131) arr at delivery centre
# ==== t: 1242.14s Δt:   0.00s [addTarget]
# createTables:     0.15s
# createLoopH:      0.15s
# ==== t: 1242.30s Δt:   0.15s [createLoopH]
# createTables:     0.10s
# Solver:           0.15s    552 Constraints
# Solver:           0.18s    554 Constraints
# Solver:           0.19s    556 Constraints
# Solver:           0.14s    558 Constraints
# Solver:           0.15s    559 Constraints
# Solver:           0.18s    560 Constraints
# Solver:           0.21s    561 Constraints
# Solver:           0.22s    562 Constraints
# createLoop:       1.51s
# ==== t: 1243.80s Δt:   1.51s [createLoop]
# [49] 13:26:33.6 Parcel: 1134 (132) arr at delivery centre
# ==== t: 1243.81s Δt:   0.00s [addTarget]
# createTables:     0.14s
# createLoopH:      0.15s
# ==== t: 1243.96s Δt:   0.15s [createLoopH]
# createTables:     0.12s
# Solver:           0.13s    600 Constraints
# Solver:           0.16s    602 Constraints
# Solver:           0.17s    604 Constraints
# Solver:           0.13s    606 Constraints
# Solver:           0.18s    607 Constraints
# Solver:           0.15s    608 Constraints
# Solver:           0.19s    609 Constraints
# Solver:           0.25s    610 Constraints
# createLoop:       1.47s
# ==== t: 1245.43s Δt:   1.47s [createLoop]
# [49] 15:12:04.0 Parcel: 1135 (146) arr at delivery centre
# ==== t: 1245.44s Δt:   0.00s [addTarget]
# createTables:     0.15s
# createLoopH:      0.15s
# ==== t: 1245.59s Δt:   0.15s [createLoopH]
# createTables:     0.13s
# Solver:           0.10s    600 Constraints
# Solver:           0.15s    601 Constraints
# Solver:           0.19s    602 Constraints
# createLoop:       0.57s
# ==== t: 1246.16s Δt:   0.57s [createLoop]
# [49] 15:14:47.5 Parcel: 1136 (146) arr at delivery centre
# [49] 15:52:00.8 Parcel: 1137 (146) arr at delivery centre
# [49] 16:05:00.6 Parcel: 1138 (148) arr at delivery centre
# ==== t: 1246.16s Δt:   0.00s [addTarget]
# createTables:     0.16s
# createLoopH:      0.16s
# ==== t: 1246.33s Δt:   0.16s [createLoopH]
# createTables:     0.14s
# Solver:           0.13s    650 Constraints
# Solver:           0.19s    653 Constraints
# Solver:           0.19s    654 Constraints
# createLoop:       0.65s
# ==== t: 1246.97s Δt:   0.65s [createLoop]
# [49] 18:00:00.0 Driver arrives for work
# [49] 18:00:00.0 Parcel: 1116 ( 36) out for delivery
# [49] 18:00:00.0 Parcel: 1120 ( 78) out for delivery
# [49] 18:00:00.0 Parcel: 1125 ( 96) out for delivery
# [49] 18:00:00.0 Parcel: 1127 (102) out for delivery
# [49] 18:00:00.0 Parcel: 1122 ( 89) out for delivery
# [49] 18:00:00.0 Parcel: 1126 ( 98) out for delivery
# [49] 18:00:00.0 Parcel: 1121 ( 83) out for delivery
# [49] 18:00:00.0 Parcel: 1111 (122) out for delivery
# [49] 18:00:00.0 Parcel: 1133 (131) out for delivery
# [49] 18:00:00.0 Parcel: 1138 (148) out for delivery
# [49] 18:00:00.0 Parcel: 1135 (146) out for delivery
# [49] 18:00:00.0 Parcel: 1136 (146) out for delivery
# [49] 18:00:00.0 Parcel: 1137 (146) out for delivery
# [49] 18:00:00.0 Parcel: 1112 (143) out for delivery
# [49] 18:00:00.0 Parcel: 1132 (127) out for delivery
# [49] 18:00:00.0 Parcel: 1131 (121) out for delivery
# [49] 18:00:00.0 Parcel: 1109 (120) out for delivery
# [49] 18:00:00.0 Parcel: 1110 (120) out for delivery
# [49] 18:00:00.0 Parcel: 1128 (109) out for delivery
# [49] 18:00:00.0 Parcel: 1123 ( 91) out for delivery
# [49] 18:00:00.0 Parcel: 1124 ( 94) out for delivery
# [49] 18:00:00.0 Parcel: 1119 ( 71) out for delivery
# [49] 18:00:00.0 Parcel: 1117 ( 49) out for delivery
# [49] 18:00:00.0 Parcel: 1118 ( 51) out for delivery
# [49] 18:00:00.0 Parcel: 1114 ( 26) out for delivery
# [49] 18:00:00.0 Parcel: 1113 ( 12) out for delivery
# [49] 18:00:00.0 Parcel: 1115 ( 31) out for delivery
# ==== t: 1246.97s Δt:   0.00s [addTarget]
# createTables:     0.08s
# createLoopH:      0.08s
# ==== t: 1247.06s Δt:   0.08s [createLoopH]
# ==== t: 1247.06s Δt:   0.00s [addTarget]
# createTables:     0.08s
# createLoopH:      0.08s
# ==== t: 1247.14s Δt:   0.09s [createLoopH]
# [49] 18:22:30.0 Driver leaves for delivery of 27 parcels
# [49] 18:22:30.0 Driver drives to Customer: 36 (2320, 6014)
# [49] 18:32:47.7 Driver arrived at Customer: 36 (2320, 6014)
# [49] 18:33:33.2 Customer: 36 (2320, 6014) answers door
# [49] 18:33:33.2 Customer: 36 (2320, 6014) accepts Parcel: 1116 ( 36)
# [49] 18:34:15.2 Customer: 36 (2320, 6014) signs off
# [49] 18:34:25.4 Driver drives to Customer: 78 (3913, 5033)
# [49] 18:45:12.6 Driver arrived at Customer: 78 (3913, 5033)
# [49] 18:46:18.7 Customer: 78 (3913, 5033) answers door
# [49] 18:46:18.7 Customer: 78 (3913, 5033) accepts Parcel: 1120 ( 78)
# [49] 20:15:42.5 Driver arrived at Customer: 71 (3719, 640)
# [49] 20:16:09.3 Customer: 71 (3719, 640) answers door
# [49] 20:16:09.3 Customer: 71 (3719, 640) accepts Parcel: 1119 ( 71)
# [49] 20:16:27.3 Customer: 71 (3719, 640) signs off
# [49] 20:16:37.3 Driver drives to Customer: 49 (2880, 1542)
# [49] 20:23:35.2 Driver arrived at Customer: 49 (2880, 1542)
# [49] 20:24:53.9 Customer: 49 (2880, 1542) answers door
# [49] 20:24:53.9 Customer: 49 (2880, 1542) accepts Parcel: 1117 ( 49)
# [49] 20:25:01.1 Customer: 49 (2880, 1542) signs off
# [49] 20:25:08.5 Driver drives to Customer: 51 (2880, 2123)
# [49] 20:27:28.0 Driver arrived at Customer: 51 (2880, 2123)
# [49] 20:28:07.6 Customer: 51 (2880, 2123) answers door
# [49] 20:28:07.6 Customer: 51 (2880, 2123) accepts Parcel: 1118 ( 51)
# [49] 20:28:20.1 Customer: 51 (2880, 2123) signs off
# [49] 20:28:33.3 Driver drives to Customer: 26 (1994, 1200)
# [49] 20:35:47.5 Driver arrived at Customer: 26 (1994, 1200)
# [49] 20:36:20.3 Customer: 26 (1994, 1200) answers door
# [49] 20:36:20.3 Customer: 26 (1994, 1200) accepts Parcel: 1114 ( 26)
# [49] 20:36:25.4 Customer: 26 (1994, 1200) signs off
# [49] 20:36:28.6 Driver drives to Customer: 12 (993, 2320)
# [49] 20:44:57.7 Driver arrived at Customer: 12 (993, 2320)
# [49] 20:45:51.2 Customer: 12 (993, 2320) answers door
# [49] 20:45:51.2 Customer: 12 (993, 2320) accepts Parcel: 1113 ( 12)
# [49] 20:45:51.8 Customer: 12 (993, 2320) signs off
# [49] 20:46:23.3 Driver drives to Customer: 31 (2126, 3633)
# [49] 20:55:57.1 Driver arrived at Customer: 31 (2126, 3633)
# [49] 20:59:00.6 Customer: 31 (2126, 3633) answers door
# [49] 20:59:00.6 Customer: 31 (2126, 3633) accepts Parcel: 1115 ( 31)
# [49] 20:59:23.3 Customer: 31 (2126, 3633) signs off
# [49] 20:59:45.1 Driver returns to delivery centre
# [49] 21:01:49.4 Driver arrived at delivery centre
# [49] 21:11:49.4 3 left over for next day
# [49] 21:11:49.4 Driver goes home
# Delivery Centre Inventory: 3 parcels

# %%
rec.reportTimer()
# Out:
# ==== t: 1232.12s Total
# ==== ΣΔt: 1093.92s createLoop
# ==== ΣΔt: 131.02s createLoopH
# ==== ΣΔt:   7.06s addTarget

# %%
with open('rec.pickle', 'rb') as f:
    sim = pickle.load(f)

# %%
rec.histWorkingTime()
rec.plotWorkingTime()
rec.statsWorkingTime()
# Out:
# (181.44, 184.5, 13.189606297600935)

# %%
rec.histTourLength()
rec.plotTourLength()
rec.statsTourLength()
# Out:
# (32779.98, 33270.5, 2060.296932136586)

# %%
rec.histLeftOver()
rec.plotLeftOver()
rec.statsLeftOver()
# Out:
# (0.7, 0.0, 1.2163847404233143)

# %%
rec.histCosts()
rec.plotCosts()
rec.statsCosts()
# Out:
# (416.71600000000007, 386.22, 61.67063390070095)

# %% [markdown]
# ## Optimisation

# %%
import pickle

with open('data.pickled', 'rb') as f:
    M, C= pickle.load(f)

def generateWarehouseLocations(M, p):

    def numberOfEdges(v, E):
        count=0
        for e in E:
            if e[0]==v or e[1]==v:
                count +=1
        return count

    V, E= M
    W = [v for v in V if numberOfEdges(v, E)>2]
    return random.sample(W, k= int(round(len(W)*p)))

def formatLocation(w):
    return f"({w[0]:4d}, {w[1]:4d})"

def objectiveFunction(w, seed=0):
    random.seed(seed)
    title = "Simulate Delivery from Warehouse "+formatLocation(w)
    rec = simulation(M, w, C, p=0.16, days=3, title=title)
    filename = "_/rec w="+formatLocation(w)+".pickled"
    with open(filename, 'wb') as f:
        pickle.dump(rec, f)
    return rec.statsTourLength()[0] # mean tour length

def MonteCarlo(M, p):

    W = generateWarehouseLocations(M,p)
    plotMap(M, T=W, styleT='bo', msT=7,
            text= "Warehouse Candidate Positions")

    minW, minP = None, math.inf
    for w in W:
        f= objectiveFunction(w)
        if f < minP:
            print(f" Improved position: {formatLocation(w):s} f={f:7.2f}")
            minW, minP = [w], f
        elif f == minP:
            print(f" Equivalent position: {formatLocation(w):s} f={f:7.2f}")
            minW.append(w)

    return minW

random.seed(7635)
W = MonteCarlo(M, 0.28)
plotMap(M, T=W, styleT='bo', msT=7, text='Best Warehouse Positions')
# Out:
# Simulate Delivery from Warehouse (2320, 2320)
#  Improved position: (2320, 2320) f=31999.33
# Simulate Delivery from Warehouse (4560, 2880)
#  Improved position: (4560, 2880) f=31804.00
# Simulate Delivery from Warehouse (5120, 4000)
# Simulate Delivery from Warehouse (1760, 1760)
# Simulate Delivery from Warehouse (3440, 4560)
# Simulate Delivery from Warehouse ( 640, 5120)
# Simulate Delivery from Warehouse (6240, 3440)
# Simulate Delivery from Warehouse (5680, 1760)
# Simulate Delivery from Warehouse (1760, 5680)
#  Improved position: (1760, 5680) f=31626.00
# Simulate Delivery from Warehouse (2880, 5680)
# Simulate Delivery from Warehouse (5680, 6240)
# Simulate Delivery from Warehouse (4560, 1200)
# Simulate Delivery from Warehouse (1760, 2880)
# Simulate Delivery from Warehouse (2320, 3440)
# Simulate Delivery from Warehouse (5120, 1760)
# Simulate Delivery from Warehouse (6240, 4560)
# Simulate Delivery from Warehouse (6800, 4000)
# Simulate Delivery from Warehouse (5120, 2880)

# %% [markdown]
# # 11. Results and Interpretation

# %%
type(rec.daily)
# Out:
# pandas.core.frame.DataFrame

# %%
df_sim = rec.daily
df_sim
# Out:
#    begin work at end work at   dist left    cost working time
# 0          64800       75761  34872    2  389.72          182
# 1         151200      162933  34862    2  389.72          195
# 2         237600      248659  33025    0  368.64          184
# 3         324000      335602  33309    0  372.64          193
# 4         410400      422385  34924    5  390.72          199
# 5         496800      509124  34703    1  387.72          205
# 6         583200      594568  34791    1  388.72          189
# 7         669600      679835  33052    0  552.64          170
# 8         756000      767016  34488    0  385.72          183
# 9         842400      852198  30698    3   513.4          163
# 10        928800      939036  31592    0  528.48          170
# 11       1015200     1026282  34528    1  385.72          184
# 12       1101600     1112432  33874    0  378.64          180
# 13       1188000     1199594  34690    1  387.72          193
# 14       1274400     1285690  33020    0  368.64          188
# 15       1360800     1372586  33503    0  374.64          196
# 16       1447200     1456773  27847    0  466.16          159
# 17       1533600     1545139  34420    0  384.72          192
# 18       1620000     1631131  33960    0  379.64          185
# 19       1706400     1715999  29991    0  501.32          159
# 20       1792800     1802469  28900    0  483.24          161
# 21       1879200     1890079  33232    0  371.64          181
# 22       1965600     1975297  30465    0   509.4          161
# 23       2052000     2063021  32430    0  362.56          183
# 24       2138400     2149673  34817    2  388.72          187
# 25       2224800     2235396  33141    1  554.64          176
# 26       2311200     2322755  33793    0  377.64          192
# 27       2397600     2407770  30629    0   512.4          169
# 28       2484000     2495452  33837    1  377.64          190
# 29       2570400     2581922  33184    0  370.64          192
# 30       2656800     2668342  34238    0  382.72          192
# 31       2743200     2752639  29158    0  487.32          157
# 32       2829600     2839228  29240    0  489.32          160
# 33       2916000     2925982  29089    0  486.32          166
# 34       3002400     3013298  31744    0  354.48          181
# 35       3088800     3100345  34629    1  386.72          192
# 36       3175200     3185620  32614    0  545.56          173
# 37       3261600     3270878  28835    0  482.24          154
# 38       3348000     3359074  34958    0  390.72          184
# 39       3434400     3445505  32412    0  362.56          185
# 40       3520800     3532171  31966    0  357.48          189
# 41       3607200     3618427  31883    0  356.48          187
# 42       3693600     3703034  28622    0  479.24          157
# 43       3780000     3791210  33903    1  378.64          186
# 44       3866400     3877489  34986    3  390.72          184
# 45       3952800     3964719  34472    0  385.72          198
# 46       4039200     4050575  34183    3  381.72          189
# 47       4125600     4137437  34447    0  384.72          197
# 48       4212000     4223342  34323    4  383.72          189
# 49       4298400     4309909  32720    3  365.56          191

# %%
df_sim= df_sim.astype(float)

# %%
df_sim.rename(columns = {'working time': 'working_time'}, inplace = True)

# %%
df_sim.describe()
# Out:
#        begin work at   end work at          dist       left        cost  \
# count   5.000000e+01  5.000000e+01     50.000000  50.000000   50.000000
# mean    2.181600e+06  2.192516e+06  32779.980000   0.700000  416.716000
# std     1.259486e+06  1.259454e+06   2060.296932   1.216385   61.670634
# min     6.480000e+04  7.576100e+04  27847.000000   0.000000  354.480000
# 25%     1.123200e+06  1.134222e+06  31778.750000   0.000000  377.640000
# 50%     2.181600e+06  2.192534e+06  33270.500000   0.000000  386.220000
# 75%     3.240000e+06  3.249564e+06  34465.750000   1.000000  481.490000
# max     4.298400e+06  4.309909e+06  34986.000000   5.000000  554.640000
#
#        working_time
# count     50.000000
# mean     181.440000
# std       13.189606
# min      154.000000
# 25%      170.750000
# 50%      184.500000
# 75%      191.750000
# max      205.000000

# %%
def cost_check(df_sim):
    df_sim['Cost_Group']=0
    for index,row in df_sim.iterrows():
        status=None
        i=row['cost']
        try:
            if (0<i<=370):
                status='Group1'
            elif (370<i<=390):
                status='Group2'
            elif (390<i<=480):
                status='Group3'
            else:
                status='Group4'
        except ValueError as err:
            pass
        df_sim['Cost_Group'].iloc[index]=status
    return df_sim

# %%
df_sim = cost_check(df_sim)
# Out:
# C:\Users\reyna\AppData\Local\Temp\ipykernel_34844\3124764089.py:17: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\reyna\AppData\Local\Temp\ipykernel_34844\3124764089.py:17: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'Group2' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.

# %%
df_sim.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   begin work at  50 non-null     float64
#  1   end work at    50 non-null     float64
#  2   dist           50 non-null     float64
#  3   left           50 non-null     float64
#  4   cost           50 non-null     float64
#  5   working_time   50 non-null     float64
#  6   Cost_Group     50 non-null     object
# dtypes: float64(6), object(1)
# memory usage: 2.9+ KB

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots

fig = make_subplots(1,3)

fig.add_trace(go.Box(
    y=df_sim['cost'],
    name='Cost',
    marker_color='darkblue',
    boxmean=True # represent mean
),1,1)
fig.add_trace(go.Box(
    y=df_sim['working_time'],
    name='Working Time',
    marker_color='royalblue',
    boxmean='sd' # represent mean and standard deviation
),1,2)
fig.add_trace(go.Box(
    y=df_sim['dist'],
    name='Length',
    marker_color='blue',
    boxmean='sd' # represent mean and standard deviation
),1,3)

fig.show()

# %%
# reshape the d dataframe suitable for statsmodels package
df_analysis= pd.DataFrame({'Group1':df_sim[df_sim['Cost_Group']=='Group1']['cost'],
                           'Group2':df_sim[df_sim['Cost_Group']=='Group2']['cost'],
                           'Group3':df_sim[df_sim['Cost_Group']=='Group3']['cost'],
                           'Group4':df_sim[df_sim['Cost_Group']=='Group4']['cost']})

# %%
df_analysis.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 50 entries, 0 to 49
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Group1  8 non-null      float64
#  1   Group2  24 non-null     float64
#  2   Group3  5 non-null      float64
#  3   Group4  13 non-null     float64
# dtypes: float64(4)
# memory usage: 2.0 KB

# %%
np.random.seed(1234)
df_sample=pd.DataFrame({'Group1':random.sample(list(df_sim['cost'][df_sim['Cost_Group']=='Group1']), 5),
                        'Group2':random.sample(list(df_sim['cost'][df_sim['Cost_Group']=='Group2']), 5),
                        'Group3':random.sample(list(df_sim['cost'][df_sim['Cost_Group']=='Group3']), 5),
                        'Group4':random.sample(list(df_sim['cost'][df_sim['Cost_Group']=='Group4']), 5)})

# %%
df_sample
# Out:
#    Group1  Group2  Group3  Group4
# 0  356.48  377.64  390.72  513.40
# 1  368.64  389.72  390.72  545.56
# 2  362.56  387.72  390.72  487.32
# 3  354.48  377.64  479.24  509.40
# 4  357.48  388.72  466.16  501.32

# %%
import scipy.stats as stats
# stats f_oneway functions takes the groups as input and returns ANOVA F and p value
fvalue, pvalue = stats.f_oneway(df_sample['Group1'],df_sample['Group2'], df_sample['Group3'], df_sample['Group4'])
print(fvalue, pvalue)
# Out:
# 34.34956329863586 3.334811111754e-07

# %%
# get ANOVA table as R like output
import statsmodels.api as sm
from statsmodels.formula.api import ols

# reshape the d dataframe suitable for statsmodels package
df_melt = pd.melt(df_sample.reset_index(), id_vars=['index'], value_vars=['Group1', 'Group2', 'Group3', 'Group4'])

# replace column names
df_melt.columns = ['index', 'simulations', 'value']

# Ordinary Least Squares (OLS) model
model = ols('value ~ simulations', data=df_melt).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
anova_table
# Out:
#                   sum_sq    df          F        PR(>F)
# simulations  66250.48088   3.0  34.349563  3.334811e-07
# Residual     10286.47424  16.0        NaN           NaN

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  value   R-squared:                       0.866
# Model:                            OLS   Adj. R-squared:                  0.840
# Method:                 Least Squares   F-statistic:                     34.35
# Date:                Fri, 12 Apr 2024   Prob (F-statistic):           3.33e-07
# Time:                        01:09:12   Log-Likelihood:                -90.807
# No. Observations:                  20   AIC:                             189.6
# Df Residuals:                      16   BIC:                             193.6
# Df Model:                           3
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept               359.9280     11.339     31.741      0.000     335.890     383.966
# simulations[T.Group2]    24.3600     16.036      1.519      0.148      -9.635      58.355
# simulations[T.Group3]    63.5840     16.036      3.965      0.001      29.589      97.579
# simulations[T.Group4]   151.4720     16.036      9.446      0.000     117.477     185.467
# ==============================================================================
# Omnibus:                        3.572   Durbin-Watson:                   1.621
# Prob(Omnibus):                  0.168   Jarque-Bera (JB):                1.921
# Skew:                           0.728   Prob(JB):                        0.383
# Kurtosis:                       3.429   Cond. No.                         4.79
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
import plotly.express as px

fig2 = px.box(df_sim, y="cost", points="all", color="Cost_Group")
fig2.show()

# %%
from statsmodels.stats.multicomp import pairwise_tukeyhsd, MultiComparison

mc = MultiComparison(df_sim['dist'], df_sim['cost'])
tukey_result = mc.tukeyhsd(alpha=0.05)

print(tukey_result)
print('Unique Cost groups: {}'.format(mc.groupsunique))
# Out:
#    Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ==========================================================
# group1 group2 meandiff p-adj    lower      upper    reject
# ----------------------------------------------------------
# 354.48 356.48    139.0 0.0995   -15.5307   293.5307  False
# 354.48 357.48    222.0 0.0027    67.4693   376.5307   True
# 354.48 362.56    677.0    0.0   543.1724   810.8276   True
# 354.48 365.56    976.0    0.0   821.4693  1130.5307   True
# 354.48 368.64   1278.5    0.0  1144.6724  1412.3276   True
# 354.48 370.64   1440.0    0.0  1285.4693  1594.5307   True
# 354.48 371.64   1488.0    0.0  1333.4693  1642.5307   True
# 354.48 372.64   1565.0    0.0  1410.4693  1719.5307   True
# 354.48 374.64   1759.0    0.0  1604.4693  1913.5307   True
# 354.48 377.64   2071.0    0.0  1937.1724  2204.8276   True
# 354.48 378.64   2144.5    0.0  2010.6724  2278.3276   True
# 354.48 379.64   2216.0    0.0  2061.4693  2370.5307   True
# 354.48 381.72   2439.0    0.0  2284.4693  2593.5307   True
# 354.48 382.72   2494.0    0.0  2339.4693  2648.5307   True
# 354.48 383.72   2579.0    0.0  2424.4693  2733.5307   True
# 354.48 384.72   2689.5    0.0  2555.6724  2823.3276   True
# 354.48 385.72   2752.0    0.0  2625.8262  2878.1738   True
# 354.48 386.72   2885.0    0.0  2730.4693  3039.5307   True
# 354.48 387.72   2952.5    0.0  2818.6724  3086.3276   True
# 354.48 388.72   3060.0    0.0  2926.1724  3193.8276   True
# 354.48 389.72   3123.0    0.0  2989.1724  3256.8276   True
# 354.48 390.72   3212.0    0.0  3085.8262  3338.1738   True
# 354.48 466.16  -3897.0    0.0 -4051.5307 -3742.4693   True
# 354.48 479.24  -3122.0    0.0 -3276.5307 -2967.4693   True
# 354.48 482.24  -2909.0    0.0 -3063.5307 -2754.4693   True
# 354.48 483.24  -2844.0    0.0 -2998.5307 -2689.4693   True
# 354.48 486.32  -2655.0    0.0 -2809.5307 -2500.4693   True
# 354.48 487.32  -2586.0    0.0 -2740.5307 -2431.4693   True
# 354.48 489.32  -2504.0    0.0 -2658.5307 -2349.4693   True
# 354.48 501.32  -1753.0    0.0 -1907.5307 -1598.4693   True
# 354.48  509.4  -1279.0    0.0 -1433.5307 -1124.4693   True
